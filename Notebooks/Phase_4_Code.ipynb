# %%
# mounting the google drive where the data csv files downloaded
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import pandas as pd
import numpy as np
import gc
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn import model_selection
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
import matplotlib
import matplotlib.pylab as plt
import seaborn as sns
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint
from scipy.stats import uniform
from xgboost import XGBClassifier
from sklearn import model_selection
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
train_data = pd.read_csv("/gdrive/My Drive/AIML/Project/training_final.csv")
useful_cols = [col for col in train_data.columns if col not in ("isFraud", "TransactionID_x", "TransactionID_y", "kfold")]
test_data = pd.read_csv("/gdrive/My Drive/AIML/Project/test_final.csv")

# %%
x_train = train_data[useful_cols].reset_index(drop=True)
y_train = train_data.isFraud

scaler = StandardScaler()
x_train_scaler = scaler.fit_transform(x_train)

pca = PCA(random_state=42)
x_train_pca = pca.fit_transform(x_train_scaler)

# %%
from prettytable import PrettyTable

fig = plt.figure(figsize=(12,8))
fig.subplots_adjust(wspace=.4, hspace=.4)

ax = fig.add_subplot(2, 1, 1)
ax.bar(range(1, 1+pca.n_components_),
       pca.explained_variance_ratio_,
       color='#FFB13F')
ax.set(xticks=range(1, 1+pca.n_components_))
plt.yticks(np.arange(0, 0.6, 0.05))
plt.title('Explained variance', fontsize=15)
plt.xlabel('Principal components', fontsize=13)
plt.ylabel('% of explained variance', fontsize=13)
# Out:
# Text(0, 0.5, '% of explained variance')

# %%
t = PrettyTable(['Component',
                 'Explained Variance',
                 'Cumulative explained variance'])
principal_component = 1
cum_explained_var = 0

for explained_var in pca.explained_variance_ratio_:
    cum_explained_var += explained_var
    t.add_row([principal_component, explained_var, cum_explained_var])
    principal_component += 1
print(t)
# Out:
# +-----------+------------------------+-------------------------------+
# | Component |   Explained Variance   | Cumulative explained variance |
# +-----------+------------------------+-------------------------------+
# |     1     |   0.4334853121189273   |       0.4334853121189273      |
# |     2     |  0.08804626290348938   |       0.5215315750224168      |
# |     3     |  0.07254098214274898   |       0.5940725571651657      |
# |     4     |  0.04920393812989916   |       0.6432764952950649      |
# |     5     |  0.037406176285218994  |       0.680682671580284       |
# |     6     |   0.0293024133260433   |       0.7099850849063273      |
# |     7     |  0.02694535911915835   |       0.7369304440254856      |
# |     8     |  0.024493022082315533  |       0.7614234661078011      |
# |     9     |   0.0225379137861635   |       0.7839613798939646      |
# |     10    |  0.019482182620140898  |       0.8034435625141055      |
# |     11    |  0.01906912319757935   |       0.8225126857116849      |
# |     12    |  0.013295523324887266  |       0.8358082090365722      |
# |     13    |  0.011885720887395026  |       0.8476939299239672      |
# |     14    |  0.010478848052323393  |       0.8581727779762905      |
# |     15    |  0.010159319424153298  |       0.8683320974004438      |
# |     16    |  0.007809550602810468  |       0.8761416480032543      |
# |     17    |  0.007317453660594855  |       0.8834591016638492      |
# |     18    |  0.006600245923756146  |       0.8900593475876054      |
# |     19    |  0.006454438725996303  |       0.8965137863136017      |
# |     20    | 0.0057804214258471345  |       0.9022942077394488      |
# |     21    | 0.0052554913566645965  |       0.9075496990961134      |
# |     22    |  0.005077915671920787  |       0.9126276147680342      |
# |     23    |  0.004944287770422622  |       0.9175719025384569      |
# |     24    |  0.004543912793237247  |       0.9221158153316942      |
# |     25    |  0.004095881371129477  |       0.9262116967028237      |
# |    420    | 5.546688734020486e-12  |       0.9999999999748653      |
# |    421    | 4.453712264134878e-12  |       0.999999999979319       |
# |    422    | 4.180332918185065e-12  |       0.9999999999834993      |
# |    423    | 3.3424198205964383e-12 |       0.9999999999868417      |
# |    424    | 3.241331713948212e-12  |       0.999999999990083       |
# |    425    | 2.626268534870644e-12  |       0.9999999999927093      |
# |    426    | 2.052561453468971e-12  |       0.9999999999947619      |
# |    427    | 1.4358537250178802e-12 |       0.9999999999961977      |
# |    428    | 1.2651036329077493e-12 |       0.9999999999974628      |
# |    429    | 1.0593759481073305e-12 |       0.9999999999985222      |
# |    430    |  9.87750646090251e-13  |        0.99999999999951       |
# |    431    | 3.910323210672501e-13  |       0.999999999999901       |
# |    432    | 9.867177144287459e-14  |       0.9999999999999997      |
# +-----------+------------------------+-------------------------------+

# %%
x_test = test_data[useful_cols].reset_index(drop=True)
y_test = test_data.isFraud
x_test_scaler = scaler.transform(x_test)
x_test_pca = pca.transform(x_test_scaler)

# %%
final_test_pred = {}

model = RandomForestClassifier(class_weight='balanced', criterion='entropy',
                       max_depth=19, min_samples_leaf=58, min_samples_split=129,
                       n_estimators=115, n_jobs=-1, random_state=2022)
model.fit(x_train_pca[:, :100],y_train)
test_preds = model.predict(x_test_pca[:, :100])

test_ids = test_data.TransactionID_x.values.tolist()
y_actual = test_data.isFraud
final_test_pred.update(dict(zip(test_ids,test_preds)))
final_test_pred = pd.DataFrame.from_dict(final_test_pred, orient="index").reset_index()
final_test_pred.columns = ["id", "pred_rf"]
final_test_pred['Actual'] = y_actual.values
final_test_pred.to_csv("/gdrive/My Drive/AIML/Project/test_pred_RF.csv", index=False)

ROC_score = roc_auc_score(final_test_pred.Actual, final_test_pred.pred_rf)
print('Test ROC Score: ', ROC_score)

print('Test confusion_matrix')
plot_confusion_matrix(final_test_pred.Actual, final_test_pred.pred_rf)
# Out:
# Test ROC Score:  0.7378132450674515
# Test confusion_matrix

# %%
def plot_confusion_matrix(y_actual, y_pred):
    #Get the confusion matrix, Precision & Re-call
    conf_matrix = confusion_matrix(y_actual, y_pred)
    recal_matrix =(((conf_matrix.T)/(conf_matrix.sum(axis=1))).T)        
    prec_matrix =(conf_matrix/conf_matrix.sum(axis=0))

    group_names = ['True Neg','False Pos','False Neg','True Pos']
    group_counts = ["{0:0.0f}".format(value) for value in
                    conf_matrix.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                        conf_matrix.flatten()/np.sum(conf_matrix)]
    labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
              zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)

    plt.figure(figsize=(20,4))
    plt.subplot(1, 3, 1)
    sns.heatmap(conf_matrix, annot=labels, fmt='', cmap='Blues')
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Confusion matrix")

    plt.subplot(1, 3, 2)
    sns.heatmap(prec_matrix, annot=True, fmt='.3f', cmap='Blues')
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Precision matrix")

    plt.subplot(1, 3, 3)
    sns.heatmap(recal_matrix, annot=True, fmt='.3f', cmap='Blues')
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Recall matrix")

    plt.show()

# %%
train_data = pd.read_csv("/gdrive/My Drive/AIML/Project/training_final.csv")
useful_cols = [col for col in train_data.columns if col not in ("isFraud", "TransactionID_x", "TransactionID_y", "kfold")]

param_dist = {"n_estimators":sp_randint(114,125),
              "max_depth": sp_randint(15,20),
              "min_samples_split": sp_randint(110,145),
              "min_samples_leaf": sp_randint(40,60),
              "criterion": ['gini' , 'entropy']}

clf = RandomForestClassifier(random_state=2022,n_jobs=-1,class_weight='balanced')

rf_random = RandomizedSearchCV(clf, param_distributions=param_dist,
                                   n_iter=10,scoring='roc_auc',random_state=2022)

x_train = train_data[useful_cols].reset_index(drop=True)
y_train = train_data.isFraud

rf_random.fit(x_train,y_train)

print(rf_random.best_estimator_)

print('mean test scores',rf_random.cv_results_['mean_test_score'])
# Out:
# RandomForestClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=19, min_samples_leaf=58, min_samples_split=129,
#                        n_estimators=115, n_jobs=-1, random_state=2022)
# mean test scores [0.87640523 0.87320511 0.87349703 0.87194447 0.87235205 0.8772915
#  0.87325046 0.87269717 0.87514224 0.87363129]

# %%
test_data = pd.read_csv("/gdrive/My Drive/AIML/Project/test_final.csv")
useful_cols = [col for col in train_data.columns if col not in ("isFraud", "TransactionID_x", "TransactionID_y", "kfold")]

x_test = test_data[useful_cols].reset_index(drop=True)
y_test = test_data.isFraud
final_test_pred = {}

model = RandomForestClassifier(class_weight='balanced', criterion='entropy',
                       max_depth=19, min_samples_leaf=58, min_samples_split=129,
                       n_estimators=115, n_jobs=-1, random_state=2022)
model.fit(x_train,y_train)
test_preds = model.predict(x_test)

test_ids = test_data.TransactionID_x.values.tolist()
y_actual = test_data.isFraud
final_test_pred.update(dict(zip(test_ids,test_preds)))
final_test_pred = pd.DataFrame.from_dict(final_test_pred, orient="index").reset_index()
final_test_pred.columns = ["id", "pred_rf"]
final_test_pred['Actual'] = y_actual.values
final_test_pred.to_csv("/gdrive/My Drive/AIML/Project/test_pred_RF.csv", index=False)

ROC_score = roc_auc_score(final_test_pred.Actual, final_test_pred.pred_rf)
print('Test ROC Score: ', ROC_score)

print('Test confusion_matrix')
plot_confusion_matrix(final_test_pred.Actual, final_test_pred.pred_rf)
# Out:
# Test ROC Score:  0.7890488919251224
# Test confusion_matrix

# %%
train_data = pd.read_csv("/gdrive/My Drive/AIML/Project/training_final.csv")
useful_cols = [col for col in train_data.columns if col not in ("isFraud", "TransactionID_x", "TransactionID_y", "kfold")]

x_train = train_data[useful_cols].reset_index(drop=True)
y_train = train_data.isFraud

idx_train = x_train.index[:int(x_train.shape[0]*0.75)]  
idx_validation = x_train.index[int(x_train.shape[0]*0.75):]

clf = XGBClassifier( 
        n_estimators=2000,
        max_depth=21, 
        learning_rate=0.02, 
        subsample=0.8,
        colsample_bytree=0.4,
        missing=-1, 
        eval_metric='auc' 
    )
model = clf.fit(x_train.loc[idx_train,useful_cols], y_train[idx_train], 
    eval_set=[(x_train.loc[idx_validation,useful_cols],y_train[idx_validation])],
    verbose=50, early_stopping_rounds=100)
# Out:
# [0]	validation_0-auc:0.835793
# Will train until validation_0-auc hasn't improved in 100 rounds.
# [50]	validation_0-auc:0.889599
# [100]	validation_0-auc:0.899066
# [150]	validation_0-auc:0.907605
# [200]	validation_0-auc:0.916782
# [250]	validation_0-auc:0.923575
# [300]	validation_0-auc:0.926901
# [350]	validation_0-auc:0.928744
# [400]	validation_0-auc:0.929083
# [450]	validation_0-auc:0.93011
# [500]	validation_0-auc:0.930408
# [550]	validation_0-auc:0.930941
# [600]	validation_0-auc:0.931393
# [650]	validation_0-auc:0.931652
# [700]	validation_0-auc:0.931825
# [750]	validation_0-auc:0.931766
# [800]	validation_0-auc:0.931958
# [850]	validation_0-auc:0.931732
# Stopping. Best iteration:
# [791]	validation_0-auc:0.932027
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-8d58f38a1e5a> in <module>()
#      21     verbose=50, early_stopping_rounds=100)
#      22
# ---> 23 print(clf.best_estimator_)
#
# AttributeError: 'XGBClassifier' object has no attribute 'best_estimator_'

# %%
test_data = pd.read_csv("/gdrive/My Drive/AIML/Project/test_final.csv")
useful_cols = [col for col in train_data.columns if col not in ("isFraud", "TransactionID_x", "TransactionID_y", "kfold")]

x_test = test_data[useful_cols].reset_index(drop=True)
y_test = test_data.isFraud
final_test_pred = {}

test_preds = model.predict(x_test)

test_ids = test_data.TransactionID_x.values.tolist()
y_actual = test_data.isFraud
final_test_pred.update(dict(zip(test_ids,test_preds)))
final_test_pred = pd.DataFrame.from_dict(final_test_pred, orient="index").reset_index()
final_test_pred.columns = ["id", "pred_xg"]
final_test_pred['Actual'] = y_actual.values
final_test_pred.to_csv("/gdrive/My Drive/AIML/Project/test_pred_xg.csv", index=False)

ROC_score = roc_auc_score(final_test_pred.Actual, final_test_pred.pred_xg)
print('Test ROC Score: ', ROC_score)

print('Test confusion_matrix')
plot_confusion_matrix(final_test_pred.Actual, final_test_pred.pred_xg)
# Out:
# Test ROC Score:  0.6476575072419901
# Test confusion_matrix

# %%
scores = []
final_valid_predictions={}

for fold in range(3):
    x_train =  train_data[train_data.kfold != fold].reset_index(drop=True)
    x_valid = train_data[train_data.kfold == fold].reset_index(drop=True)

    valid_ids = x_valid.TransactionID_x.values.tolist()
    
    y_train = x_train.isFraud
    y_valid = x_valid.isFraud
    

    x_train = x_train[useful_cols]
    x_valid = x_valid[useful_cols]
       
    model1 = XGBClassifier(random_state=fold, n_jobs=-1)
    model1.fit(x_train, y_train)
    preds_valid = model1.predict(x_valid)
    final_valid_predictions.update(dict(zip(valid_ids, preds_valid)))
    ROC_score = roc_auc_score(y_valid, preds_valid)
    print(fold, ROC_score)
    scores.append(ROC_score)

print(np.mean(scores), np.std(scores))
final_valid_predictions = pd.DataFrame.from_dict(final_valid_predictions, orient="index").reset_index()
final_valid_predictions.columns = ["id", "pred_1"]
final_valid_predictions.to_csv("/gdrive/My Drive/AIML/Project/train_pred_1.csv", index=False)
# Out:
# 0 0.6487102496969612
# 1 0.6467916510672247
# 2 0.6478909454876526
# 0.6477976154172795 0.0007860398853466278

# %%
final_test_pred = {}
test_ids = test_data.TransactionID_x.values.tolist()
y_actual = test_data.isFraud
x_test = test_data[useful_cols]
test_preds = model1.predict(x_test)
final_test_pred.update(dict(zip(test_ids,test_preds)))
final_test_pred = pd.DataFrame.from_dict(final_test_pred, orient="index").reset_index()
final_test_pred.columns = ["id", "pred_1"]
final_test_pred['Actual'] = y_actual.values
final_test_pred.to_csv("/gdrive/My Drive/AIML/Project/test_pred_1.csv", index=False)

ROC_score = roc_auc_score(final_test_pred.Actual, final_test_pred.pred_1)
print('Test ROC Score: ', ROC_score)
# Out:
# Test ROC Score:  0.6340990963357974

# %%
print('Test confusion_matrix')
plot_confusion_matrix(final_test_pred.Actual, final_test_pred.pred_1)
# Out:
# Test confusion_matrix

# %%
import tensorflow as tf
from tensorflow import keras
import os
import tempfile
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

cleaned_df = pd.read_csv("/gdrive/My Drive/AIML/Project/training_final.csv")
test_df = pd.read_csv("/gdrive/My Drive/AIML/Project/test_final.csv")

neg, pos = np.bincount(cleaned_df['isFraud'])
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))

# You don't want the `Time` column.
cleaned_df.pop('TransactionDT')
cleaned_df.pop('kfold')
cleaned_df.pop('TransactionID_x')
cleaned_df.pop('TransactionID_y')
test_df.pop('TransactionDT')
test_df.pop('kfold')
test_df.pop('TransactionID_x')
test_df.pop('TransactionID_y')

# The `Amount` column covers a huge range. Convert to log-space.
eps = 0.001 # 0 => 0.1¢
cleaned_df['Log Ammount'] = np.log(cleaned_df.pop('TransactionAmt')+eps)
test_df['Log Ammount'] = np.log(test_df.pop('TransactionAmt')+eps)

# Use a utility from sklearn to split and shuffle your dataset.
train_df, val_df = train_test_split(cleaned_df, test_size=0.2)

# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
weight_for_0 = (1 / neg) * (total / 2.0)
weight_for_1 = (1 / pos) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Examples:
#     Total: 472432
#     Positive: 16599 (3.51% of total)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
# Weight for class 0: 0.52
# Weight for class 1: 14.23

# %%
# Form np arrays of labels and features.
train_labels = np.array(train_df.pop('isFraud'))
bool_train_labels = train_labels != 0
val_labels = np.array(val_df.pop('isFraud'))
test_labels = np.array(test_df.pop('isFraud'))

train_features = np.array(train_df)
val_features = np.array(val_df)
test_features = np.array(test_df)

print('Training features shape:', train_features.shape)
print('Validation features shape:', val_features.shape)
print('Test features shape:', test_features.shape)

scaler = StandardScaler()
train_features = scaler.fit_transform(train_features)

val_features = scaler.transform(val_features)
test_features = scaler.transform(test_features)

train_features = np.clip(train_features, -5, 5)
val_features = np.clip(val_features, -5, 5)
test_features = np.clip(test_features, -5, 5)

print('Training labels shape:', train_labels.shape)
print('Validation labels shape:', val_labels.shape)
print('Test labels shape:', test_labels.shape)
# Out:
# Training features shape: (377945, 431)
# Validation features shape: (94487, 431)
# Test features shape: (118108, 431)
# Training labels shape: (377945,)
# Validation labels shape: (94487,)
# Test labels shape: (118108,)

# %%
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc', curve="ROC"),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

def make_model(metrics=METRICS, output_bias=None):
  if output_bias is not None:
    output_bias = tf.keras.initializers.Constant(output_bias)
  model = keras.Sequential([
      keras.layers.Dense(
          256, activation='relu',
          input_shape=(train_features.shape[-1],)),
      keras.layers.Dropout(0.5),
      keras.layers.Dense(
          128, activation='relu',
          input_shape=(train_features.shape[-1],)),
      keras.layers.Dropout(0.5),
      keras.layers.Dense(
          64, activation='relu',
          input_shape=(train_features.shape[-1],)),
      keras.layers.Dropout(0.5),
            keras.layers.Dense(
          16, activation='relu',
          input_shape=(train_features.shape[-1],)),
      keras.layers.Dropout(0.5),
      keras.layers.Dense(1, activation='sigmoid',
          bias_initializer=output_bias),
  ])

  model.compile(
      optimizer=keras.optimizers.Adam(learning_rate=1e-3),
      loss=keras.losses.BinaryCrossentropy(),
      metrics=metrics)

  return model

# %%
EPOCHS = 200
BATCH_SIZE = 4096
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_prc', 
    verbose=1,
    patience=10,
    mode='max',
    restore_best_weights=True)

# %%
weighted_model = make_model()
#weighted_model.load_weights(initial_weights)
weighted_model.summary()

weighted_history = weighted_model.fit(
    train_features,
    train_labels,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=[early_stopping],
    validation_data=(val_features, val_labels),
    # The class weights go here
    class_weight=class_weight)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               110592
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 16)                1040
#
#  dropout_3 (Dropout)         (None, 16)                0
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 152,801
# Trainable params: 152,801
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 93/93 [==============================] - 13s 108ms/step - loss: 0.6851 - tp: 6010.0000 - fp: 76420.0000 - tn: 288216.0000 - fn: 7299.0000 - accuracy: 0.7785 - precision: 0.0729 - recall: 0.4516 - auc: 0.6509 - prc: 0.0745 - val_loss: 0.4762 - val_tp: 1866.0000 - val_fp: 12401.0000 - val_tn: 78796.0000 - val_fn: 1424.0000 - val_accuracy: 0.8537 - val_precision: 0.1308 - val_recall: 0.5672 - val_auc: 0.8093 - val_prc: 0.1823
# Epoch 2/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.5985 - tp: 7668.0000 - fp: 71089.0000 - tn: 293547.0000 - fn: 5641.0000 - accuracy: 0.7970 - precision: 0.0974 - recall: 0.5762 - auc: 0.7565 - prc: 0.1243 - val_loss: 0.4551 - val_tp: 1862.0000 - val_fp: 9821.0000 - val_tn: 81376.0000 - val_fn: 1428.0000 - val_accuracy: 0.8809 - val_precision: 0.1594 - val_recall: 0.5660 - val_auc: 0.8316 - val_prc: 0.2264
# Epoch 3/200
# 93/93 [==============================] - 9s 94ms/step - loss: 0.5689 - tp: 8188.0000 - fp: 68189.0000 - tn: 296447.0000 - fn: 5121.0000 - accuracy: 0.8060 - precision: 0.1072 - recall: 0.6152 - auc: 0.7882 - prc: 0.1644 - val_loss: 0.4514 - val_tp: 2055.0000 - val_fp: 12192.0000 - val_tn: 79005.0000 - val_fn: 1235.0000 - val_accuracy: 0.8579 - val_precision: 0.1442 - val_recall: 0.6246 - val_auc: 0.8404 - val_prc: 0.2811
# Epoch 4/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.5526 - tp: 8397.0000 - fp: 64707.0000 - tn: 299929.0000 - fn: 4912.0000 - accuracy: 0.8158 - precision: 0.1149 - recall: 0.6309 - auc: 0.8020 - prc: 0.1895 - val_loss: 0.4312 - val_tp: 2062.0000 - val_fp: 11134.0000 - val_tn: 80063.0000 - val_fn: 1228.0000 - val_accuracy: 0.8692 - val_precision: 0.1563 - val_recall: 0.6267 - val_auc: 0.8480 - val_prc: 0.3056
# Epoch 5/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.5418 - tp: 8620.0000 - fp: 63566.0000 - tn: 301070.0000 - fn: 4689.0000 - accuracy: 0.8194 - precision: 0.1194 - recall: 0.6477 - auc: 0.8123 - prc: 0.2124 - val_loss: 0.4689 - val_tp: 2138.0000 - val_fp: 11126.0000 - val_tn: 80071.0000 - val_fn: 1152.0000 - val_accuracy: 0.8701 - val_precision: 0.1612 - val_recall: 0.6498 - val_auc: 0.8558 - val_prc: 0.3283
# Epoch 6/200
# 93/93 [==============================] - 9s 94ms/step - loss: 0.5322 - tp: 8624.0000 - fp: 61620.0000 - tn: 303016.0000 - fn: 4685.0000 - accuracy: 0.8246 - precision: 0.1228 - recall: 0.6480 - auc: 0.8182 - prc: 0.2289 - val_loss: 0.4367 - val_tp: 2108.0000 - val_fp: 9929.0000 - val_tn: 81268.0000 - val_fn: 1182.0000 - val_accuracy: 0.8824 - val_precision: 0.1751 - val_recall: 0.6407 - val_auc: 0.8591 - val_prc: 0.3476
# Epoch 7/200
# 93/93 [==============================] - 9s 94ms/step - loss: 0.5263 - tp: 8859.0000 - fp: 62047.0000 - tn: 302589.0000 - fn: 4450.0000 - accuracy: 0.8241 - precision: 0.1249 - recall: 0.6656 - auc: 0.8234 - prc: 0.2429 - val_loss: 0.4519 - val_tp: 2176.0000 - val_fp: 11532.0000 - val_tn: 79665.0000 - val_fn: 1114.0000 - val_accuracy: 0.8662 - val_precision: 0.1587 - val_recall: 0.6614 - val_auc: 0.8593 - val_prc: 0.3571
# Epoch 8/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.5188 - tp: 8889.0000 - fp: 58958.0000 - tn: 305678.0000 - fn: 4420.0000 - accuracy: 0.8323 - precision: 0.1310 - recall: 0.6679 - auc: 0.8283 - prc: 0.2610 - val_loss: 0.4232 - val_tp: 2151.0000 - val_fp: 10116.0000 - val_tn: 81081.0000 - val_fn: 1139.0000 - val_accuracy: 0.8809 - val_precision: 0.1753 - val_recall: 0.6538 - val_auc: 0.8638 - val_prc: 0.3765
# Epoch 9/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.5144 - tp: 8951.0000 - fp: 59425.0000 - tn: 305211.0000 - fn: 4358.0000 - accuracy: 0.8312 - precision: 0.1309 - recall: 0.6726 - auc: 0.8310 - prc: 0.2674 - val_loss: 0.4222 - val_tp: 2074.0000 - val_fp: 9449.0000 - val_tn: 81748.0000 - val_fn: 1216.0000 - val_accuracy: 0.8871 - val_precision: 0.1800 - val_recall: 0.6304 - val_auc: 0.8604 - val_prc: 0.3637
# Epoch 10/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.5091 - tp: 9056.0000 - fp: 59385.0000 - tn: 305251.0000 - fn: 4253.0000 - accuracy: 0.8316 - precision: 0.1323 - recall: 0.6804 - auc: 0.8345 - prc: 0.2780 - val_loss: 0.4333 - val_tp: 2061.0000 - val_fp: 8640.0000 - val_tn: 82557.0000 - val_fn: 1229.0000 - val_accuracy: 0.8956 - val_precision: 0.1926 - val_recall: 0.6264 - val_auc: 0.8655 - val_prc: 0.3738
# Epoch 11/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.5060 - tp: 9121.0000 - fp: 59444.0000 - tn: 305192.0000 - fn: 4188.0000 - accuracy: 0.8316 - precision: 0.1330 - recall: 0.6853 - auc: 0.8366 - prc: 0.2869 - val_loss: 0.4617 - val_tp: 2256.0000 - val_fp: 11373.0000 - val_tn: 79824.0000 - val_fn: 1034.0000 - val_accuracy: 0.8687 - val_precision: 0.1655 - val_recall: 0.6857 - val_auc: 0.8673 - val_prc: 0.3817
# Epoch 12/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.5023 - tp: 9148.0000 - fp: 58749.0000 - tn: 305887.0000 - fn: 4161.0000 - accuracy: 0.8335 - precision: 0.1347 - recall: 0.6874 - auc: 0.8385 - prc: 0.2949 - val_loss: 0.4059 - val_tp: 2035.0000 - val_fp: 7805.0000 - val_tn: 83392.0000 - val_fn: 1255.0000 - val_accuracy: 0.9041 - val_precision: 0.2068 - val_recall: 0.6185 - val_auc: 0.8639 - val_prc: 0.3887
# Epoch 13/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.5010 - tp: 9188.0000 - fp: 59645.0000 - tn: 304991.0000 - fn: 4121.0000 - accuracy: 0.8313 - precision: 0.1335 - recall: 0.6904 - auc: 0.8388 - prc: 0.3007 - val_loss: 0.4036 - val_tp: 2095.0000 - val_fp: 8166.0000 - val_tn: 83031.0000 - val_fn: 1195.0000 - val_accuracy: 0.9009 - val_precision: 0.2042 - val_recall: 0.6368 - val_auc: 0.8702 - val_prc: 0.3945
# Epoch 14/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4998 - tp: 9163.0000 - fp: 58194.0000 - tn: 306442.0000 - fn: 4146.0000 - accuracy: 0.8351 - precision: 0.1360 - recall: 0.6885 - auc: 0.8401 - prc: 0.2974 - val_loss: 0.4323 - val_tp: 2180.0000 - val_fp: 9142.0000 - val_tn: 82055.0000 - val_fn: 1110.0000 - val_accuracy: 0.8915 - val_precision: 0.1925 - val_recall: 0.6626 - val_auc: 0.8712 - val_prc: 0.3949
# Epoch 15/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4955 - tp: 9277.0000 - fp: 59012.0000 - tn: 305624.0000 - fn: 4032.0000 - accuracy: 0.8332 - precision: 0.1358 - recall: 0.6970 - auc: 0.8435 - prc: 0.3060 - val_loss: 0.4318 - val_tp: 2330.0000 - val_fp: 12430.0000 - val_tn: 78767.0000 - val_fn: 960.0000 - val_accuracy: 0.8583 - val_precision: 0.1579 - val_recall: 0.7082 - val_auc: 0.8723 - val_prc: 0.4127
# Epoch 16/200
# 93/93 [==============================] - 9s 94ms/step - loss: 0.4929 - tp: 9261.0000 - fp: 57244.0000 - tn: 307392.0000 - fn: 4048.0000 - accuracy: 0.8378 - precision: 0.1393 - recall: 0.6958 - auc: 0.8443 - prc: 0.3160 - val_loss: 0.4377 - val_tp: 2278.0000 - val_fp: 11423.0000 - val_tn: 79774.0000 - val_fn: 1012.0000 - val_accuracy: 0.8684 - val_precision: 0.1663 - val_recall: 0.6924 - val_auc: 0.8738 - val_prc: 0.4080
# Epoch 17/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4919 - tp: 9306.0000 - fp: 59126.0000 - tn: 305510.0000 - fn: 4003.0000 - accuracy: 0.8330 - precision: 0.1360 - recall: 0.6992 - auc: 0.8457 - prc: 0.3156 - val_loss: 0.4490 - val_tp: 2340.0000 - val_fp: 13253.0000 - val_tn: 77944.0000 - val_fn: 950.0000 - val_accuracy: 0.8497 - val_precision: 0.1501 - val_recall: 0.7112 - val_auc: 0.8702 - val_prc: 0.4069
# Epoch 18/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4900 - tp: 9317.0000 - fp: 58822.0000 - tn: 305814.0000 - fn: 3992.0000 - accuracy: 0.8338 - precision: 0.1367 - recall: 0.7001 - auc: 0.8461 - prc: 0.3199 - val_loss: 0.4559 - val_tp: 2374.0000 - val_fp: 13320.0000 - val_tn: 77877.0000 - val_fn: 916.0000 - val_accuracy: 0.8493 - val_precision: 0.1513 - val_recall: 0.7216 - val_auc: 0.8748 - val_prc: 0.4223
# Epoch 19/200
# 93/93 [==============================] - 9s 94ms/step - loss: 0.4877 - tp: 9416.0000 - fp: 58466.0000 - tn: 306170.0000 - fn: 3893.0000 - accuracy: 0.8350 - precision: 0.1387 - recall: 0.7075 - auc: 0.8477 - prc: 0.3263 - val_loss: 0.4145 - val_tp: 2247.0000 - val_fp: 10445.0000 - val_tn: 80752.0000 - val_fn: 1043.0000 - val_accuracy: 0.8784 - val_precision: 0.1770 - val_recall: 0.6830 - val_auc: 0.8751 - val_prc: 0.4204
# Epoch 20/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4844 - tp: 9428.0000 - fp: 58063.0000 - tn: 306573.0000 - fn: 3881.0000 - accuracy: 0.8361 - precision: 0.1397 - recall: 0.7084 - auc: 0.8493 - prc: 0.3265 - val_loss: 0.4268 - val_tp: 2271.0000 - val_fp: 10404.0000 - val_tn: 80793.0000 - val_fn: 1019.0000 - val_accuracy: 0.8791 - val_precision: 0.1792 - val_recall: 0.6903 - val_auc: 0.8768 - val_prc: 0.4215
# Epoch 21/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4811 - tp: 9515.0000 - fp: 58002.0000 - tn: 306634.0000 - fn: 3794.0000 - accuracy: 0.8365 - precision: 0.1409 - recall: 0.7149 - auc: 0.8522 - prc: 0.3337 - val_loss: 0.4313 - val_tp: 2368.0000 - val_fp: 12969.0000 - val_tn: 78228.0000 - val_fn: 922.0000 - val_accuracy: 0.8530 - val_precision: 0.1544 - val_recall: 0.7198 - val_auc: 0.8720 - val_prc: 0.4115
# Epoch 22/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4818 - tp: 9489.0000 - fp: 58777.0000 - tn: 305859.0000 - fn: 3820.0000 - accuracy: 0.8344 - precision: 0.1390 - recall: 0.7130 - auc: 0.8507 - prc: 0.3369 - val_loss: 0.3990 - val_tp: 2220.0000 - val_fp: 8961.0000 - val_tn: 82236.0000 - val_fn: 1070.0000 - val_accuracy: 0.8938 - val_precision: 0.1986 - val_recall: 0.6748 - val_auc: 0.8776 - val_prc: 0.4220
# Epoch 23/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4820 - tp: 9462.0000 - fp: 58522.0000 - tn: 306114.0000 - fn: 3847.0000 - accuracy: 0.8350 - precision: 0.1392 - recall: 0.7109 - auc: 0.8510 - prc: 0.3338 - val_loss: 0.4084 - val_tp: 2316.0000 - val_fp: 11230.0000 - val_tn: 79967.0000 - val_fn: 974.0000 - val_accuracy: 0.8708 - val_precision: 0.1710 - val_recall: 0.7040 - val_auc: 0.8771 - val_prc: 0.4323
# Epoch 24/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4833 - tp: 9449.0000 - fp: 56578.0000 - tn: 308058.0000 - fn: 3860.0000 - accuracy: 0.8401 - precision: 0.1431 - recall: 0.7100 - auc: 0.8509 - prc: 0.3332 - val_loss: 0.4144 - val_tp: 2251.0000 - val_fp: 9647.0000 - val_tn: 81550.0000 - val_fn: 1039.0000 - val_accuracy: 0.8869 - val_precision: 0.1892 - val_recall: 0.6842 - val_auc: 0.8781 - val_prc: 0.4358
# Epoch 25/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4780 - tp: 9501.0000 - fp: 56806.0000 - tn: 307830.0000 - fn: 3808.0000 - accuracy: 0.8396 - precision: 0.1433 - recall: 0.7139 - auc: 0.8539 - prc: 0.3468 - val_loss: 0.4593 - val_tp: 2427.0000 - val_fp: 14449.0000 - val_tn: 76748.0000 - val_fn: 863.0000 - val_accuracy: 0.8379 - val_precision: 0.1438 - val_recall: 0.7377 - val_auc: 0.8737 - val_prc: 0.4149
# Epoch 26/200
# 93/93 [==============================] - 9s 94ms/step - loss: 0.4754 - tp: 9547.0000 - fp: 57250.0000 - tn: 307386.0000 - fn: 3762.0000 - accuracy: 0.8386 - precision: 0.1429 - recall: 0.7173 - auc: 0.8556 - prc: 0.3436 - val_loss: 0.3975 - val_tp: 2327.0000 - val_fp: 10898.0000 - val_tn: 80299.0000 - val_fn: 963.0000 - val_accuracy: 0.8745 - val_precision: 0.1760 - val_recall: 0.7073 - val_auc: 0.8800 - val_prc: 0.4360
# Epoch 27/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4756 - tp: 9633.0000 - fp: 59203.0000 - tn: 305433.0000 - fn: 3676.0000 - accuracy: 0.8336 - precision: 0.1399 - recall: 0.7238 - auc: 0.8558 - prc: 0.3487 - val_loss: 0.3990 - val_tp: 2290.0000 - val_fp: 10053.0000 - val_tn: 81144.0000 - val_fn: 1000.0000 - val_accuracy: 0.8830 - val_precision: 0.1855 - val_recall: 0.6960 - val_auc: 0.8811 - val_prc: 0.4322
# Epoch 28/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4725 - tp: 9588.0000 - fp: 57683.0000 - tn: 306953.0000 - fn: 3721.0000 - accuracy: 0.8375 - precision: 0.1425 - recall: 0.7204 - auc: 0.8570 - prc: 0.3506 - val_loss: 0.3755 - val_tp: 2254.0000 - val_fp: 9151.0000 - val_tn: 82046.0000 - val_fn: 1036.0000 - val_accuracy: 0.8922 - val_precision: 0.1976 - val_recall: 0.6851 - val_auc: 0.8826 - val_prc: 0.4421
# Epoch 29/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4724 - tp: 9692.0000 - fp: 58610.0000 - tn: 306026.0000 - fn: 3617.0000 - accuracy: 0.8354 - precision: 0.1419 - recall: 0.7282 - auc: 0.8574 - prc: 0.3522 - val_loss: 0.3999 - val_tp: 2296.0000 - val_fp: 10093.0000 - val_tn: 81104.0000 - val_fn: 994.0000 - val_accuracy: 0.8827 - val_precision: 0.1853 - val_recall: 0.6979 - val_auc: 0.8786 - val_prc: 0.4302
# Epoch 30/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4737 - tp: 9650.0000 - fp: 58375.0000 - tn: 306261.0000 - fn: 3659.0000 - accuracy: 0.8359 - precision: 0.1419 - recall: 0.7251 - auc: 0.8561 - prc: 0.3545 - val_loss: 0.4088 - val_tp: 2372.0000 - val_fp: 11568.0000 - val_tn: 79629.0000 - val_fn: 918.0000 - val_accuracy: 0.8679 - val_precision: 0.1702 - val_recall: 0.7210 - val_auc: 0.8833 - val_prc: 0.4492
# Epoch 31/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4722 - tp: 9639.0000 - fp: 57384.0000 - tn: 307252.0000 - fn: 3670.0000 - accuracy: 0.8385 - precision: 0.1438 - recall: 0.7242 - auc: 0.8573 - prc: 0.3580 - val_loss: 0.3834 - val_tp: 2275.0000 - val_fp: 9510.0000 - val_tn: 81687.0000 - val_fn: 1015.0000 - val_accuracy: 0.8886 - val_precision: 0.1930 - val_recall: 0.6915 - val_auc: 0.8835 - val_prc: 0.4512
# Epoch 32/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4689 - tp: 9717.0000 - fp: 58856.0000 - tn: 305780.0000 - fn: 3592.0000 - accuracy: 0.8348 - precision: 0.1417 - recall: 0.7301 - auc: 0.8596 - prc: 0.3585 - val_loss: 0.3952 - val_tp: 2302.0000 - val_fp: 10048.0000 - val_tn: 81149.0000 - val_fn: 988.0000 - val_accuracy: 0.8832 - val_precision: 0.1864 - val_recall: 0.6997 - val_auc: 0.8828 - val_prc: 0.4529
# Epoch 33/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4698 - tp: 9711.0000 - fp: 57444.0000 - tn: 307192.0000 - fn: 3598.0000 - accuracy: 0.8385 - precision: 0.1446 - recall: 0.7297 - auc: 0.8589 - prc: 0.3653 - val_loss: 0.3832 - val_tp: 2294.0000 - val_fp: 9579.0000 - val_tn: 81618.0000 - val_fn: 996.0000 - val_accuracy: 0.8881 - val_precision: 0.1932 - val_recall: 0.6973 - val_auc: 0.8837 - val_prc: 0.4584
# Epoch 34/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4690 - tp: 9691.0000 - fp: 57264.0000 - tn: 307372.0000 - fn: 3618.0000 - accuracy: 0.8389 - precision: 0.1447 - recall: 0.7282 - auc: 0.8593 - prc: 0.3626 - val_loss: 0.3825 - val_tp: 2252.0000 - val_fp: 9206.0000 - val_tn: 81991.0000 - val_fn: 1038.0000 - val_accuracy: 0.8916 - val_precision: 0.1965 - val_recall: 0.6845 - val_auc: 0.8797 - val_prc: 0.4424
# Epoch 35/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4654 - tp: 9748.0000 - fp: 57023.0000 - tn: 307613.0000 - fn: 3561.0000 - accuracy: 0.8397 - precision: 0.1460 - recall: 0.7324 - auc: 0.8615 - prc: 0.3712 - val_loss: 0.4133 - val_tp: 2330.0000 - val_fp: 10283.0000 - val_tn: 80914.0000 - val_fn: 960.0000 - val_accuracy: 0.8810 - val_precision: 0.1847 - val_recall: 0.7082 - val_auc: 0.8845 - val_prc: 0.4583
# Epoch 36/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4668 - tp: 9649.0000 - fp: 55526.0000 - tn: 309110.0000 - fn: 3660.0000 - accuracy: 0.8434 - precision: 0.1480 - recall: 0.7250 - auc: 0.8612 - prc: 0.3675 - val_loss: 0.3615 - val_tp: 2240.0000 - val_fp: 8221.0000 - val_tn: 82976.0000 - val_fn: 1050.0000 - val_accuracy: 0.9019 - val_precision: 0.2141 - val_recall: 0.6809 - val_auc: 0.8854 - val_prc: 0.4570
# Epoch 37/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4640 - tp: 9735.0000 - fp: 56727.0000 - tn: 307909.0000 - fn: 3574.0000 - accuracy: 0.8405 - precision: 0.1465 - recall: 0.7315 - auc: 0.8626 - prc: 0.3679 - val_loss: 0.3705 - val_tp: 2334.0000 - val_fp: 10065.0000 - val_tn: 81132.0000 - val_fn: 956.0000 - val_accuracy: 0.8834 - val_precision: 0.1882 - val_recall: 0.7094 - val_auc: 0.8844 - val_prc: 0.4570
# Epoch 38/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4651 - tp: 9671.0000 - fp: 55561.0000 - tn: 309075.0000 - fn: 3638.0000 - accuracy: 0.8434 - precision: 0.1483 - recall: 0.7267 - auc: 0.8615 - prc: 0.3741 - val_loss: 0.4192 - val_tp: 2417.0000 - val_fp: 12643.0000 - val_tn: 78554.0000 - val_fn: 873.0000 - val_accuracy: 0.8570 - val_precision: 0.1605 - val_recall: 0.7347 - val_auc: 0.8816 - val_prc: 0.4552
# Epoch 39/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4614 - tp: 9813.0000 - fp: 57678.0000 - tn: 306958.0000 - fn: 3496.0000 - accuracy: 0.8381 - precision: 0.1454 - recall: 0.7373 - auc: 0.8638 - prc: 0.3738 - val_loss: 0.3892 - val_tp: 2326.0000 - val_fp: 10012.0000 - val_tn: 81185.0000 - val_fn: 964.0000 - val_accuracy: 0.8838 - val_precision: 0.1885 - val_recall: 0.7070 - val_auc: 0.8853 - val_prc: 0.4653
# Epoch 40/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4625 - tp: 9764.0000 - fp: 56270.0000 - tn: 308366.0000 - fn: 3545.0000 - accuracy: 0.8417 - precision: 0.1479 - recall: 0.7336 - auc: 0.8637 - prc: 0.3729 - val_loss: 0.3974 - val_tp: 2366.0000 - val_fp: 10443.0000 - val_tn: 80754.0000 - val_fn: 924.0000 - val_accuracy: 0.8797 - val_precision: 0.1847 - val_recall: 0.7191 - val_auc: 0.8861 - val_prc: 0.4646
# Epoch 41/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4607 - tp: 9882.0000 - fp: 58032.0000 - tn: 306604.0000 - fn: 3427.0000 - accuracy: 0.8374 - precision: 0.1455 - recall: 0.7425 - auc: 0.8640 - prc: 0.3723 - val_loss: 0.4099 - val_tp: 2404.0000 - val_fp: 11602.0000 - val_tn: 79595.0000 - val_fn: 886.0000 - val_accuracy: 0.8678 - val_precision: 0.1716 - val_recall: 0.7307 - val_auc: 0.8843 - val_prc: 0.4608
# Epoch 42/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4613 - tp: 9833.0000 - fp: 58192.0000 - tn: 306444.0000 - fn: 3476.0000 - accuracy: 0.8368 - precision: 0.1445 - recall: 0.7388 - auc: 0.8637 - prc: 0.3770 - val_loss: 0.4053 - val_tp: 2396.0000 - val_fp: 11212.0000 - val_tn: 79985.0000 - val_fn: 894.0000 - val_accuracy: 0.8719 - val_precision: 0.1761 - val_recall: 0.7283 - val_auc: 0.8865 - val_prc: 0.4553
# Epoch 43/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4603 - tp: 9858.0000 - fp: 58463.0000 - tn: 306173.0000 - fn: 3451.0000 - accuracy: 0.8362 - precision: 0.1443 - recall: 0.7407 - auc: 0.8650 - prc: 0.3800 - val_loss: 0.3949 - val_tp: 2426.0000 - val_fp: 11741.0000 - val_tn: 79456.0000 - val_fn: 864.0000 - val_accuracy: 0.8666 - val_precision: 0.1712 - val_recall: 0.7374 - val_auc: 0.8874 - val_prc: 0.4657
# Epoch 44/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4590 - tp: 9842.0000 - fp: 56380.0000 - tn: 308256.0000 - fn: 3467.0000 - accuracy: 0.8417 - precision: 0.1486 - recall: 0.7395 - auc: 0.8653 - prc: 0.3816 - val_loss: 0.4225 - val_tp: 2483.0000 - val_fp: 13278.0000 - val_tn: 77919.0000 - val_fn: 807.0000 - val_accuracy: 0.8509 - val_precision: 0.1575 - val_recall: 0.7547 - val_auc: 0.8864 - val_prc: 0.4587
# Epoch 45/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4555 - tp: 9875.0000 - fp: 57206.0000 - tn: 307430.0000 - fn: 3434.0000 - accuracy: 0.8396 - precision: 0.1472 - recall: 0.7420 - auc: 0.8672 - prc: 0.3836 - val_loss: 0.3655 - val_tp: 2274.0000 - val_fp: 8610.0000 - val_tn: 82587.0000 - val_fn: 1016.0000 - val_accuracy: 0.8981 - val_precision: 0.2089 - val_recall: 0.6912 - val_auc: 0.8878 - val_prc: 0.4676
# Epoch 46/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4543 - tp: 9955.0000 - fp: 57645.0000 - tn: 306991.0000 - fn: 3354.0000 - accuracy: 0.8386 - precision: 0.1473 - recall: 0.7480 - auc: 0.8676 - prc: 0.3862 - val_loss: 0.3796 - val_tp: 2305.0000 - val_fp: 9169.0000 - val_tn: 82028.0000 - val_fn: 985.0000 - val_accuracy: 0.8925 - val_precision: 0.2009 - val_recall: 0.7006 - val_auc: 0.8879 - val_prc: 0.4690
# Epoch 47/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4584 - tp: 9880.0000 - fp: 56486.0000 - tn: 308150.0000 - fn: 3429.0000 - accuracy: 0.8415 - precision: 0.1489 - recall: 0.7424 - auc: 0.8658 - prc: 0.3826 - val_loss: 0.3910 - val_tp: 2395.0000 - val_fp: 11097.0000 - val_tn: 80100.0000 - val_fn: 895.0000 - val_accuracy: 0.8731 - val_precision: 0.1775 - val_recall: 0.7280 - val_auc: 0.8883 - val_prc: 0.4713
# Epoch 48/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4560 - tp: 9862.0000 - fp: 56553.0000 - tn: 308083.0000 - fn: 3447.0000 - accuracy: 0.8412 - precision: 0.1485 - recall: 0.7410 - auc: 0.8676 - prc: 0.3881 - val_loss: 0.4067 - val_tp: 2413.0000 - val_fp: 11234.0000 - val_tn: 79963.0000 - val_fn: 877.0000 - val_accuracy: 0.8718 - val_precision: 0.1768 - val_recall: 0.7334 - val_auc: 0.8886 - val_prc: 0.4747
# Epoch 49/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4561 - tp: 9898.0000 - fp: 56030.0000 - tn: 308606.0000 - fn: 3411.0000 - accuracy: 0.8427 - precision: 0.1501 - recall: 0.7437 - auc: 0.8674 - prc: 0.3823 - val_loss: 0.3876 - val_tp: 2278.0000 - val_fp: 8703.0000 - val_tn: 82494.0000 - val_fn: 1012.0000 - val_accuracy: 0.8972 - val_precision: 0.2074 - val_recall: 0.6924 - val_auc: 0.8865 - val_prc: 0.4674
# Epoch 50/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4566 - tp: 9834.0000 - fp: 55091.0000 - tn: 309545.0000 - fn: 3475.0000 - accuracy: 0.8450 - precision: 0.1515 - recall: 0.7389 - auc: 0.8664 - prc: 0.3889 - val_loss: 0.3919 - val_tp: 2466.0000 - val_fp: 12341.0000 - val_tn: 78856.0000 - val_fn: 824.0000 - val_accuracy: 0.8607 - val_precision: 0.1665 - val_recall: 0.7495 - val_auc: 0.8897 - val_prc: 0.4791
# Epoch 51/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4546 - tp: 9907.0000 - fp: 56909.0000 - tn: 307727.0000 - fn: 3402.0000 - accuracy: 0.8404 - precision: 0.1483 - recall: 0.7444 - auc: 0.8685 - prc: 0.3893 - val_loss: 0.3865 - val_tp: 2422.0000 - val_fp: 10859.0000 - val_tn: 80338.0000 - val_fn: 868.0000 - val_accuracy: 0.8759 - val_precision: 0.1824 - val_recall: 0.7362 - val_auc: 0.8901 - val_prc: 0.4752
# Epoch 52/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4545 - tp: 9903.0000 - fp: 56606.0000 - tn: 308030.0000 - fn: 3406.0000 - accuracy: 0.8412 - precision: 0.1489 - recall: 0.7441 - auc: 0.8685 - prc: 0.3874 - val_loss: 0.3901 - val_tp: 2416.0000 - val_fp: 10809.0000 - val_tn: 80388.0000 - val_fn: 874.0000 - val_accuracy: 0.8764 - val_precision: 0.1827 - val_recall: 0.7343 - val_auc: 0.8909 - val_prc: 0.4828
# Epoch 53/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4536 - tp: 9915.0000 - fp: 57346.0000 - tn: 307290.0000 - fn: 3394.0000 - accuracy: 0.8393 - precision: 0.1474 - recall: 0.7450 - auc: 0.8686 - prc: 0.3908 - val_loss: 0.3655 - val_tp: 2271.0000 - val_fp: 8838.0000 - val_tn: 82359.0000 - val_fn: 1019.0000 - val_accuracy: 0.8957 - val_precision: 0.2044 - val_recall: 0.6903 - val_auc: 0.8883 - val_prc: 0.4637
# Epoch 54/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4516 - tp: 9912.0000 - fp: 54643.0000 - tn: 309993.0000 - fn: 3397.0000 - accuracy: 0.8464 - precision: 0.1535 - recall: 0.7448 - auc: 0.8697 - prc: 0.3997 - val_loss: 0.3921 - val_tp: 2377.0000 - val_fp: 10515.0000 - val_tn: 80682.0000 - val_fn: 913.0000 - val_accuracy: 0.8791 - val_precision: 0.1844 - val_recall: 0.7225 - val_auc: 0.8872 - val_prc: 0.4708
# Epoch 55/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4503 - tp: 9933.0000 - fp: 55753.0000 - tn: 308883.0000 - fn: 3376.0000 - accuracy: 0.8436 - precision: 0.1512 - recall: 0.7463 - auc: 0.8707 - prc: 0.3959 - val_loss: 0.3720 - val_tp: 2393.0000 - val_fp: 10179.0000 - val_tn: 81018.0000 - val_fn: 897.0000 - val_accuracy: 0.8828 - val_precision: 0.1903 - val_recall: 0.7274 - val_auc: 0.8895 - val_prc: 0.4765
# Epoch 56/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4517 - tp: 9958.0000 - fp: 57284.0000 - tn: 307352.0000 - fn: 3351.0000 - accuracy: 0.8396 - precision: 0.1481 - recall: 0.7482 - auc: 0.8700 - prc: 0.3960 - val_loss: 0.3748 - val_tp: 2350.0000 - val_fp: 9421.0000 - val_tn: 81776.0000 - val_fn: 940.0000 - val_accuracy: 0.8903 - val_precision: 0.1996 - val_recall: 0.7143 - val_auc: 0.8910 - val_prc: 0.4895
# Epoch 57/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4489 - tp: 9933.0000 - fp: 56653.0000 - tn: 307983.0000 - fn: 3376.0000 - accuracy: 0.8412 - precision: 0.1492 - recall: 0.7463 - auc: 0.8712 - prc: 0.4020 - val_loss: 0.3792 - val_tp: 2446.0000 - val_fp: 11457.0000 - val_tn: 79740.0000 - val_fn: 844.0000 - val_accuracy: 0.8698 - val_precision: 0.1759 - val_recall: 0.7435 - val_auc: 0.8913 - val_prc: 0.4873
# Epoch 58/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4480 - tp: 9961.0000 - fp: 56701.0000 - tn: 307935.0000 - fn: 3348.0000 - accuracy: 0.8411 - precision: 0.1494 - recall: 0.7484 - auc: 0.8722 - prc: 0.3998 - val_loss: 0.4011 - val_tp: 2478.0000 - val_fp: 12793.0000 - val_tn: 78404.0000 - val_fn: 812.0000 - val_accuracy: 0.8560 - val_precision: 0.1623 - val_recall: 0.7532 - val_auc: 0.8898 - val_prc: 0.4905
# Epoch 59/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4492 - tp: 9944.0000 - fp: 56511.0000 - tn: 308125.0000 - fn: 3365.0000 - accuracy: 0.8416 - precision: 0.1496 - recall: 0.7472 - auc: 0.8713 - prc: 0.4072 - val_loss: 0.3928 - val_tp: 2438.0000 - val_fp: 11836.0000 - val_tn: 79361.0000 - val_fn: 852.0000 - val_accuracy: 0.8657 - val_precision: 0.1708 - val_recall: 0.7410 - val_auc: 0.8901 - val_prc: 0.4819
# Epoch 60/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4531 - tp: 9892.0000 - fp: 58336.0000 - tn: 306300.0000 - fn: 3417.0000 - accuracy: 0.8366 - precision: 0.1450 - recall: 0.7433 - auc: 0.8691 - prc: 0.3912 - val_loss: 0.3944 - val_tp: 2449.0000 - val_fp: 11629.0000 - val_tn: 79568.0000 - val_fn: 841.0000 - val_accuracy: 0.8680 - val_precision: 0.1740 - val_recall: 0.7444 - val_auc: 0.8912 - val_prc: 0.4886
# Epoch 61/200
# 93/93 [==============================] - 9s 95ms/step - loss: 0.4495 - tp: 9925.0000 - fp: 56124.0000 - tn: 308512.0000 - fn: 3384.0000 - accuracy: 0.8425 - precision: 0.1503 - recall: 0.7457 - auc: 0.8714 - prc: 0.3989 - val_loss: 0.3609 - val_tp: 2407.0000 - val_fp: 10611.0000 - val_tn: 80586.0000 - val_fn: 883.0000 - val_accuracy: 0.8784 - val_precision: 0.1849 - val_recall: 0.7316 - val_auc: 0.8920 - val_prc: 0.4889
# Epoch 62/200
# 93/93 [==============================] - 12s 129ms/step - loss: 0.4473 - tp: 9931.0000 - fp: 56017.0000 - tn: 308619.0000 - fn: 3378.0000 - accuracy: 0.8428 - precision: 0.1506 - recall: 0.7462 - auc: 0.8725 - prc: 0.3998 - val_loss: 0.3817 - val_tp: 2434.0000 - val_fp: 11666.0000 - val_tn: 79531.0000 - val_fn: 856.0000 - val_accuracy: 0.8675 - val_precision: 0.1726 - val_recall: 0.7398 - val_auc: 0.8900 - val_prc: 0.4877
# Epoch 63/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4478 - tp: 9985.0000 - fp: 56565.0000 - tn: 308071.0000 - fn: 3324.0000 - accuracy: 0.8415 - precision: 0.1500 - recall: 0.7502 - auc: 0.8721 - prc: 0.4036 - val_loss: 0.3920 - val_tp: 2428.0000 - val_fp: 10982.0000 - val_tn: 80215.0000 - val_fn: 862.0000 - val_accuracy: 0.8746 - val_precision: 0.1811 - val_recall: 0.7380 - val_auc: 0.8915 - val_prc: 0.4912
# Epoch 64/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4464 - tp: 9947.0000 - fp: 55475.0000 - tn: 309161.0000 - fn: 3362.0000 - accuracy: 0.8443 - precision: 0.1520 - recall: 0.7474 - auc: 0.8722 - prc: 0.4082 - val_loss: 0.3719 - val_tp: 2382.0000 - val_fp: 10244.0000 - val_tn: 80953.0000 - val_fn: 908.0000 - val_accuracy: 0.8820 - val_precision: 0.1887 - val_recall: 0.7240 - val_auc: 0.8917 - val_prc: 0.4948
# Epoch 65/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4466 - tp: 9966.0000 - fp: 55350.0000 - tn: 309286.0000 - fn: 3343.0000 - accuracy: 0.8447 - precision: 0.1526 - recall: 0.7488 - auc: 0.8727 - prc: 0.4058 - val_loss: 0.3991 - val_tp: 2450.0000 - val_fp: 11585.0000 - val_tn: 79612.0000 - val_fn: 840.0000 - val_accuracy: 0.8685 - val_precision: 0.1746 - val_recall: 0.7447 - val_auc: 0.8923 - val_prc: 0.4864
# Epoch 66/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4471 - tp: 9925.0000 - fp: 53821.0000 - tn: 310815.0000 - fn: 3384.0000 - accuracy: 0.8486 - precision: 0.1557 - recall: 0.7457 - auc: 0.8732 - prc: 0.4080 - val_loss: 0.3758 - val_tp: 2433.0000 - val_fp: 10980.0000 - val_tn: 80217.0000 - val_fn: 857.0000 - val_accuracy: 0.8747 - val_precision: 0.1814 - val_recall: 0.7395 - val_auc: 0.8927 - val_prc: 0.4948
# Epoch 67/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4438 - tp: 10016.0000 - fp: 54561.0000 - tn: 310075.0000 - fn: 3293.0000 - accuracy: 0.8469 - precision: 0.1551 - recall: 0.7526 - auc: 0.8748 - prc: 0.4096 - val_loss: 0.3438 - val_tp: 2360.0000 - val_fp: 9320.0000 - val_tn: 81877.0000 - val_fn: 930.0000 - val_accuracy: 0.8915 - val_precision: 0.2021 - val_recall: 0.7173 - val_auc: 0.8925 - val_prc: 0.5027
# Epoch 68/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4445 - tp: 10060.0000 - fp: 56264.0000 - tn: 308372.0000 - fn: 3249.0000 - accuracy: 0.8425 - precision: 0.1517 - recall: 0.7559 - auc: 0.8747 - prc: 0.4061 - val_loss: 0.3890 - val_tp: 2465.0000 - val_fp: 12144.0000 - val_tn: 79053.0000 - val_fn: 825.0000 - val_accuracy: 0.8627 - val_precision: 0.1687 - val_recall: 0.7492 - val_auc: 0.8927 - val_prc: 0.4890
# Epoch 69/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4441 - tp: 9985.0000 - fp: 55115.0000 - tn: 309521.0000 - fn: 3324.0000 - accuracy: 0.8454 - precision: 0.1534 - recall: 0.7502 - auc: 0.8743 - prc: 0.4091 - val_loss: 0.3400 - val_tp: 2328.0000 - val_fp: 8844.0000 - val_tn: 82353.0000 - val_fn: 962.0000 - val_accuracy: 0.8962 - val_precision: 0.2084 - val_recall: 0.7076 - val_auc: 0.8936 - val_prc: 0.4969
# Epoch 70/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4449 - tp: 9939.0000 - fp: 53757.0000 - tn: 310879.0000 - fn: 3370.0000 - accuracy: 0.8488 - precision: 0.1560 - recall: 0.7468 - auc: 0.8738 - prc: 0.4091 - val_loss: 0.3997 - val_tp: 2489.0000 - val_fp: 12601.0000 - val_tn: 78596.0000 - val_fn: 801.0000 - val_accuracy: 0.8582 - val_precision: 0.1649 - val_recall: 0.7565 - val_auc: 0.8919 - val_prc: 0.4879
# Epoch 71/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4425 - tp: 10014.0000 - fp: 54713.0000 - tn: 309923.0000 - fn: 3295.0000 - accuracy: 0.8465 - precision: 0.1547 - recall: 0.7524 - auc: 0.8752 - prc: 0.4153 - val_loss: 0.3848 - val_tp: 2412.0000 - val_fp: 10359.0000 - val_tn: 80838.0000 - val_fn: 878.0000 - val_accuracy: 0.8811 - val_precision: 0.1889 - val_recall: 0.7331 - val_auc: 0.8920 - val_prc: 0.4961
# Epoch 72/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4421 - tp: 10009.0000 - fp: 53195.0000 - tn: 311441.0000 - fn: 3300.0000 - accuracy: 0.8505 - precision: 0.1584 - recall: 0.7520 - auc: 0.8754 - prc: 0.4156 - val_loss: 0.3823 - val_tp: 2438.0000 - val_fp: 10727.0000 - val_tn: 80470.0000 - val_fn: 852.0000 - val_accuracy: 0.8775 - val_precision: 0.1852 - val_recall: 0.7410 - val_auc: 0.8936 - val_prc: 0.5053
# Epoch 73/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4435 - tp: 9937.0000 - fp: 53872.0000 - tn: 310764.0000 - fn: 3372.0000 - accuracy: 0.8485 - precision: 0.1557 - recall: 0.7466 - auc: 0.8745 - prc: 0.4115 - val_loss: 0.4002 - val_tp: 2491.0000 - val_fp: 12266.0000 - val_tn: 78931.0000 - val_fn: 799.0000 - val_accuracy: 0.8617 - val_precision: 0.1688 - val_recall: 0.7571 - val_auc: 0.8944 - val_prc: 0.5053
# Epoch 74/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4413 - tp: 10038.0000 - fp: 54754.0000 - tn: 309882.0000 - fn: 3271.0000 - accuracy: 0.8465 - precision: 0.1549 - recall: 0.7542 - auc: 0.8764 - prc: 0.4125 - val_loss: 0.3731 - val_tp: 2441.0000 - val_fp: 10608.0000 - val_tn: 80589.0000 - val_fn: 849.0000 - val_accuracy: 0.8787 - val_precision: 0.1871 - val_recall: 0.7419 - val_auc: 0.8947 - val_prc: 0.4966
# Epoch 75/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4418 - tp: 10054.0000 - fp: 54599.0000 - tn: 310037.0000 - fn: 3255.0000 - accuracy: 0.8469 - precision: 0.1555 - recall: 0.7554 - auc: 0.8762 - prc: 0.4148 - val_loss: 0.3653 - val_tp: 2423.0000 - val_fp: 10482.0000 - val_tn: 80715.0000 - val_fn: 867.0000 - val_accuracy: 0.8799 - val_precision: 0.1878 - val_recall: 0.7365 - val_auc: 0.8939 - val_prc: 0.4987
# Epoch 76/200
# 93/93 [==============================] - 9s 96ms/step - loss: 0.4391 - tp: 10102.0000 - fp: 55464.0000 - tn: 309172.0000 - fn: 3207.0000 - accuracy: 0.8448 - precision: 0.1541 - recall: 0.7590 - auc: 0.8775 - prc: 0.4191 - val_loss: 0.3776 - val_tp: 2475.0000 - val_fp: 11264.0000 - val_tn: 79933.0000 - val_fn: 815.0000 - val_accuracy: 0.8722 - val_precision: 0.1801 - val_recall: 0.7523 - val_auc: 0.8946 - val_prc: 0.5058
# Epoch 77/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4392 - tp: 10080.0000 - fp: 54911.0000 - tn: 309725.0000 - fn: 3229.0000 - accuracy: 0.8462 - precision: 0.1551 - recall: 0.7574 - auc: 0.8778 - prc: 0.4226 - val_loss: 0.3792 - val_tp: 2430.0000 - val_fp: 10430.0000 - val_tn: 80767.0000 - val_fn: 860.0000 - val_accuracy: 0.8805 - val_precision: 0.1890 - val_recall: 0.7386 - val_auc: 0.8942 - val_prc: 0.4982
# Epoch 78/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4420 - tp: 10004.0000 - fp: 53972.0000 - tn: 310664.0000 - fn: 3305.0000 - accuracy: 0.8485 - precision: 0.1564 - recall: 0.7517 - auc: 0.8758 - prc: 0.4110 - val_loss: 0.3804 - val_tp: 2451.0000 - val_fp: 10821.0000 - val_tn: 80376.0000 - val_fn: 839.0000 - val_accuracy: 0.8766 - val_precision: 0.1847 - val_recall: 0.7450 - val_auc: 0.8941 - val_prc: 0.4977
# Epoch 79/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4369 - tp: 10103.0000 - fp: 54473.0000 - tn: 310163.0000 - fn: 3206.0000 - accuracy: 0.8474 - precision: 0.1565 - recall: 0.7591 - auc: 0.8788 - prc: 0.4238 - val_loss: 0.3647 - val_tp: 2422.0000 - val_fp: 10143.0000 - val_tn: 81054.0000 - val_fn: 868.0000 - val_accuracy: 0.8835 - val_precision: 0.1928 - val_recall: 0.7362 - val_auc: 0.8949 - val_prc: 0.5002
# Epoch 80/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4388 - tp: 10069.0000 - fp: 55218.0000 - tn: 309418.0000 - fn: 3240.0000 - accuracy: 0.8453 - precision: 0.1542 - recall: 0.7566 - auc: 0.8776 - prc: 0.4202 - val_loss: 0.3609 - val_tp: 2399.0000 - val_fp: 9911.0000 - val_tn: 81286.0000 - val_fn: 891.0000 - val_accuracy: 0.8857 - val_precision: 0.1949 - val_recall: 0.7292 - val_auc: 0.8938 - val_prc: 0.5061
# Epoch 81/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4375 - tp: 10051.0000 - fp: 54758.0000 - tn: 309878.0000 - fn: 3258.0000 - accuracy: 0.8465 - precision: 0.1551 - recall: 0.7552 - auc: 0.8781 - prc: 0.4215 - val_loss: 0.3558 - val_tp: 2370.0000 - val_fp: 9321.0000 - val_tn: 81876.0000 - val_fn: 920.0000 - val_accuracy: 0.8916 - val_precision: 0.2027 - val_recall: 0.7204 - val_auc: 0.8952 - val_prc: 0.5102
# Epoch 82/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4376 - tp: 10091.0000 - fp: 54639.0000 - tn: 309997.0000 - fn: 3218.0000 - accuracy: 0.8469 - precision: 0.1559 - recall: 0.7582 - auc: 0.8786 - prc: 0.4225 - val_loss: 0.3817 - val_tp: 2458.0000 - val_fp: 11215.0000 - val_tn: 79982.0000 - val_fn: 832.0000 - val_accuracy: 0.8725 - val_precision: 0.1798 - val_recall: 0.7471 - val_auc: 0.8942 - val_prc: 0.4981
# Epoch 83/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4356 - tp: 10151.0000 - fp: 54966.0000 - tn: 309670.0000 - fn: 3158.0000 - accuracy: 0.8462 - precision: 0.1559 - recall: 0.7627 - auc: 0.8798 - prc: 0.4257 - val_loss: 0.3744 - val_tp: 2429.0000 - val_fp: 10428.0000 - val_tn: 80769.0000 - val_fn: 861.0000 - val_accuracy: 0.8805 - val_precision: 0.1889 - val_recall: 0.7383 - val_auc: 0.8946 - val_prc: 0.5095
# Epoch 84/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4359 - tp: 10101.0000 - fp: 55313.0000 - tn: 309323.0000 - fn: 3208.0000 - accuracy: 0.8452 - precision: 0.1544 - recall: 0.7590 - auc: 0.8791 - prc: 0.4280 - val_loss: 0.3607 - val_tp: 2399.0000 - val_fp: 9833.0000 - val_tn: 81364.0000 - val_fn: 891.0000 - val_accuracy: 0.8865 - val_precision: 0.1961 - val_recall: 0.7292 - val_auc: 0.8956 - val_prc: 0.5089
# Epoch 85/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4371 - tp: 10005.0000 - fp: 53593.0000 - tn: 311043.0000 - fn: 3304.0000 - accuracy: 0.8495 - precision: 0.1573 - recall: 0.7517 - auc: 0.8786 - prc: 0.4264 - val_loss: 0.3781 - val_tp: 2445.0000 - val_fp: 10713.0000 - val_tn: 80484.0000 - val_fn: 845.0000 - val_accuracy: 0.8777 - val_precision: 0.1858 - val_recall: 0.7432 - val_auc: 0.8950 - val_prc: 0.4973
# Epoch 86/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4338 - tp: 10116.0000 - fp: 54309.0000 - tn: 310327.0000 - fn: 3193.0000 - accuracy: 0.8479 - precision: 0.1570 - recall: 0.7601 - auc: 0.8806 - prc: 0.4275 - val_loss: 0.3684 - val_tp: 2428.0000 - val_fp: 10388.0000 - val_tn: 80809.0000 - val_fn: 862.0000 - val_accuracy: 0.8809 - val_precision: 0.1895 - val_recall: 0.7380 - val_auc: 0.8960 - val_prc: 0.5136
# Epoch 87/200
# 93/93 [==============================] - 9s 97ms/step - loss: 0.4359 - tp: 10113.0000 - fp: 54907.0000 - tn: 309729.0000 - fn: 3196.0000 - accuracy: 0.8463 - precision: 0.1555 - recall: 0.7599 - auc: 0.8793 - prc: 0.4270 - val_loss: 0.3566 - val_tp: 2373.0000 - val_fp: 8963.0000 - val_tn: 82234.0000 - val_fn: 917.0000 - val_accuracy: 0.8954 - val_precision: 0.2093 - val_recall: 0.7213 - val_auc: 0.8951 - val_prc: 0.5101
# Epoch 88/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4369 - tp: 10035.0000 - fp: 53914.0000 - tn: 310722.0000 - fn: 3274.0000 - accuracy: 0.8487 - precision: 0.1569 - recall: 0.7540 - auc: 0.8792 - prc: 0.4211 - val_loss: 0.3579 - val_tp: 2412.0000 - val_fp: 10224.0000 - val_tn: 80973.0000 - val_fn: 878.0000 - val_accuracy: 0.8825 - val_precision: 0.1909 - val_recall: 0.7331 - val_auc: 0.8958 - val_prc: 0.5104
# Epoch 89/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4345 - tp: 10135.0000 - fp: 54003.0000 - tn: 310633.0000 - fn: 3174.0000 - accuracy: 0.8487 - precision: 0.1580 - recall: 0.7615 - auc: 0.8802 - prc: 0.4220 - val_loss: 0.3776 - val_tp: 2497.0000 - val_fp: 11892.0000 - val_tn: 79305.0000 - val_fn: 793.0000 - val_accuracy: 0.8657 - val_precision: 0.1735 - val_recall: 0.7590 - val_auc: 0.8954 - val_prc: 0.5032
# Epoch 90/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4335 - tp: 10211.0000 - fp: 55703.0000 - tn: 308933.0000 - fn: 3098.0000 - accuracy: 0.8444 - precision: 0.1549 - recall: 0.7672 - auc: 0.8811 - prc: 0.4304 - val_loss: 0.3575 - val_tp: 2404.0000 - val_fp: 9772.0000 - val_tn: 81425.0000 - val_fn: 886.0000 - val_accuracy: 0.8872 - val_precision: 0.1974 - val_recall: 0.7307 - val_auc: 0.8957 - val_prc: 0.5057
# Epoch 91/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4360 - tp: 10071.0000 - fp: 53526.0000 - tn: 311110.0000 - fn: 3238.0000 - accuracy: 0.8498 - precision: 0.1584 - recall: 0.7567 - auc: 0.8787 - prc: 0.4301 - val_loss: 0.3805 - val_tp: 2489.0000 - val_fp: 11584.0000 - val_tn: 79613.0000 - val_fn: 801.0000 - val_accuracy: 0.8689 - val_precision: 0.1769 - val_recall: 0.7565 - val_auc: 0.8957 - val_prc: 0.5178
# Epoch 92/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4342 - tp: 10122.0000 - fp: 54398.0000 - tn: 310238.0000 - fn: 3187.0000 - accuracy: 0.8476 - precision: 0.1569 - recall: 0.7605 - auc: 0.8806 - prc: 0.4275 - val_loss: 0.3773 - val_tp: 2508.0000 - val_fp: 12523.0000 - val_tn: 78674.0000 - val_fn: 782.0000 - val_accuracy: 0.8592 - val_precision: 0.1669 - val_recall: 0.7623 - val_auc: 0.8953 - val_prc: 0.5160
# Epoch 93/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4329 - tp: 10152.0000 - fp: 54883.0000 - tn: 309753.0000 - fn: 3157.0000 - accuracy: 0.8464 - precision: 0.1561 - recall: 0.7628 - auc: 0.8810 - prc: 0.4305 - val_loss: 0.3647 - val_tp: 2463.0000 - val_fp: 11120.0000 - val_tn: 80077.0000 - val_fn: 827.0000 - val_accuracy: 0.8736 - val_precision: 0.1813 - val_recall: 0.7486 - val_auc: 0.8963 - val_prc: 0.5133
# Epoch 94/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4290 - tp: 10168.0000 - fp: 54341.0000 - tn: 310295.0000 - fn: 3141.0000 - accuracy: 0.8479 - precision: 0.1576 - recall: 0.7640 - auc: 0.8833 - prc: 0.4342 - val_loss: 0.3582 - val_tp: 2461.0000 - val_fp: 10946.0000 - val_tn: 80251.0000 - val_fn: 829.0000 - val_accuracy: 0.8754 - val_precision: 0.1836 - val_recall: 0.7480 - val_auc: 0.8965 - val_prc: 0.5147
# Epoch 95/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4336 - tp: 10135.0000 - fp: 55047.0000 - tn: 309589.0000 - fn: 3174.0000 - accuracy: 0.8460 - precision: 0.1555 - recall: 0.7615 - auc: 0.8813 - prc: 0.4307 - val_loss: 0.3781 - val_tp: 2460.0000 - val_fp: 10723.0000 - val_tn: 80474.0000 - val_fn: 830.0000 - val_accuracy: 0.8777 - val_precision: 0.1866 - val_recall: 0.7477 - val_auc: 0.8967 - val_prc: 0.5088
# Epoch 96/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4328 - tp: 10141.0000 - fp: 54536.0000 - tn: 310100.0000 - fn: 3168.0000 - accuracy: 0.8473 - precision: 0.1568 - recall: 0.7620 - auc: 0.8810 - prc: 0.4303 - val_loss: 0.3727 - val_tp: 2506.0000 - val_fp: 11996.0000 - val_tn: 79201.0000 - val_fn: 784.0000 - val_accuracy: 0.8647 - val_precision: 0.1728 - val_recall: 0.7617 - val_auc: 0.8972 - val_prc: 0.5149
# Epoch 97/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4306 - tp: 10145.0000 - fp: 54048.0000 - tn: 310588.0000 - fn: 3164.0000 - accuracy: 0.8486 - precision: 0.1580 - recall: 0.7623 - auc: 0.8821 - prc: 0.4323 - val_loss: 0.3679 - val_tp: 2490.0000 - val_fp: 11471.0000 - val_tn: 79726.0000 - val_fn: 800.0000 - val_accuracy: 0.8701 - val_precision: 0.1784 - val_recall: 0.7568 - val_auc: 0.8980 - val_prc: 0.5173
# Epoch 98/200
# 93/93 [==============================] - 9s 101ms/step - loss: 0.4311 - tp: 10198.0000 - fp: 55033.0000 - tn: 309603.0000 - fn: 3111.0000 - accuracy: 0.8462 - precision: 0.1563 - recall: 0.7662 - auc: 0.8817 - prc: 0.4363 - val_loss: 0.3575 - val_tp: 2476.0000 - val_fp: 11146.0000 - val_tn: 80051.0000 - val_fn: 814.0000 - val_accuracy: 0.8734 - val_precision: 0.1818 - val_recall: 0.7526 - val_auc: 0.8966 - val_prc: 0.5167
# Epoch 99/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4301 - tp: 10213.0000 - fp: 55320.0000 - tn: 309316.0000 - fn: 3096.0000 - accuracy: 0.8454 - precision: 0.1558 - recall: 0.7674 - auc: 0.8828 - prc: 0.4369 - val_loss: 0.3693 - val_tp: 2478.0000 - val_fp: 10898.0000 - val_tn: 80299.0000 - val_fn: 812.0000 - val_accuracy: 0.8761 - val_precision: 0.1853 - val_recall: 0.7532 - val_auc: 0.8970 - val_prc: 0.5123
# Epoch 100/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4309 - tp: 10181.0000 - fp: 54409.0000 - tn: 310227.0000 - fn: 3128.0000 - accuracy: 0.8478 - precision: 0.1576 - recall: 0.7650 - auc: 0.8823 - prc: 0.4368 - val_loss: 0.3660 - val_tp: 2439.0000 - val_fp: 10130.0000 - val_tn: 81067.0000 - val_fn: 851.0000 - val_accuracy: 0.8838 - val_precision: 0.1940 - val_recall: 0.7413 - val_auc: 0.8970 - val_prc: 0.5183
# Epoch 101/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4330 - tp: 10133.0000 - fp: 54995.0000 - tn: 309641.0000 - fn: 3176.0000 - accuracy: 0.8461 - precision: 0.1556 - recall: 0.7614 - auc: 0.8812 - prc: 0.4348 - val_loss: 0.3691 - val_tp: 2471.0000 - val_fp: 10859.0000 - val_tn: 80338.0000 - val_fn: 819.0000 - val_accuracy: 0.8764 - val_precision: 0.1854 - val_recall: 0.7511 - val_auc: 0.8979 - val_prc: 0.5199
# Epoch 102/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4317 - tp: 10136.0000 - fp: 52950.0000 - tn: 311686.0000 - fn: 3173.0000 - accuracy: 0.8515 - precision: 0.1607 - recall: 0.7616 - auc: 0.8820 - prc: 0.4336 - val_loss: 0.3537 - val_tp: 2416.0000 - val_fp: 10067.0000 - val_tn: 81130.0000 - val_fn: 874.0000 - val_accuracy: 0.8842 - val_precision: 0.1935 - val_recall: 0.7343 - val_auc: 0.8957 - val_prc: 0.5211
# Epoch 103/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4292 - tp: 10151.0000 - fp: 52010.0000 - tn: 312626.0000 - fn: 3158.0000 - accuracy: 0.8540 - precision: 0.1633 - recall: 0.7627 - auc: 0.8832 - prc: 0.4378 - val_loss: 0.3537 - val_tp: 2447.0000 - val_fp: 10344.0000 - val_tn: 80853.0000 - val_fn: 843.0000 - val_accuracy: 0.8816 - val_precision: 0.1913 - val_recall: 0.7438 - val_auc: 0.8971 - val_prc: 0.5204
# Epoch 104/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4288 - tp: 10250.0000 - fp: 55439.0000 - tn: 309197.0000 - fn: 3059.0000 - accuracy: 0.8452 - precision: 0.1560 - recall: 0.7702 - auc: 0.8835 - prc: 0.4328 - val_loss: 0.3654 - val_tp: 2497.0000 - val_fp: 11595.0000 - val_tn: 79602.0000 - val_fn: 793.0000 - val_accuracy: 0.8689 - val_precision: 0.1772 - val_recall: 0.7590 - val_auc: 0.8963 - val_prc: 0.5154
# Epoch 105/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4290 - tp: 10189.0000 - fp: 54069.0000 - tn: 310567.0000 - fn: 3120.0000 - accuracy: 0.8487 - precision: 0.1586 - recall: 0.7656 - auc: 0.8836 - prc: 0.4345 - val_loss: 0.3581 - val_tp: 2458.0000 - val_fp: 10372.0000 - val_tn: 80825.0000 - val_fn: 832.0000 - val_accuracy: 0.8814 - val_precision: 0.1916 - val_recall: 0.7471 - val_auc: 0.8983 - val_prc: 0.5231
# Epoch 106/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4269 - tp: 10177.0000 - fp: 53081.0000 - tn: 311555.0000 - fn: 3132.0000 - accuracy: 0.8513 - precision: 0.1609 - recall: 0.7647 - auc: 0.8846 - prc: 0.4409 - val_loss: 0.3498 - val_tp: 2429.0000 - val_fp: 9885.0000 - val_tn: 81312.0000 - val_fn: 861.0000 - val_accuracy: 0.8863 - val_precision: 0.1973 - val_recall: 0.7383 - val_auc: 0.8992 - val_prc: 0.5213
# Epoch 107/200
# ...
# Epoch 128/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4216 - tp: 10243.0000 - fp: 53633.0000 - tn: 311003.0000 - fn: 3066.0000 - accuracy: 0.8500 - precision: 0.1604 - recall: 0.7696 - auc: 0.8892 - prc: 0.4448 - val_loss: 0.3749 - val_tp: 2513.0000 - val_fp: 11503.0000 - val_tn: 79694.0000 - val_fn: 777.0000 - val_accuracy: 0.8700 - val_precision: 0.1793 - val_recall: 0.7638 - val_auc: 0.9001 - val_prc: 0.5314
# Epoch 129/200
# 93/93 [==============================] - 12s 131ms/step - loss: 0.4191 - tp: 10231.0000 - fp: 52896.0000 - tn: 311740.0000 - fn: 3078.0000 - accuracy: 0.8519 - precision: 0.1621 - recall: 0.7687 - auc: 0.8891 - prc: 0.4527 - val_loss: 0.3643 - val_tp: 2511.0000 - val_fp: 11163.0000 - val_tn: 80034.0000 - val_fn: 779.0000 - val_accuracy: 0.8736 - val_precision: 0.1836 - val_recall: 0.7632 - val_auc: 0.9014 - val_prc: 0.5352
# Epoch 130/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4209 - tp: 10232.0000 - fp: 53113.0000 - tn: 311523.0000 - fn: 3077.0000 - accuracy: 0.8513 - precision: 0.1615 - recall: 0.7688 - auc: 0.8883 - prc: 0.4509 - val_loss: 0.3598 - val_tp: 2519.0000 - val_fp: 11665.0000 - val_tn: 79532.0000 - val_fn: 771.0000 - val_accuracy: 0.8684 - val_precision: 0.1776 - val_recall: 0.7657 - val_auc: 0.8987 - val_prc: 0.5271
# Epoch 131/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4189 - tp: 10286.0000 - fp: 53795.0000 - tn: 310841.0000 - fn: 3023.0000 - accuracy: 0.8497 - precision: 0.1605 - recall: 0.7729 - auc: 0.8889 - prc: 0.4534 - val_loss: 0.3575 - val_tp: 2491.0000 - val_fp: 10941.0000 - val_tn: 80256.0000 - val_fn: 799.0000 - val_accuracy: 0.8758 - val_precision: 0.1855 - val_recall: 0.7571 - val_auc: 0.9011 - val_prc: 0.5324
# Epoch 132/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4211 - tp: 10219.0000 - fp: 52806.0000 - tn: 311830.0000 - fn: 3090.0000 - accuracy: 0.8521 - precision: 0.1621 - recall: 0.7678 - auc: 0.8880 - prc: 0.4482 - val_loss: 0.3473 - val_tp: 2511.0000 - val_fp: 10768.0000 - val_tn: 80429.0000 - val_fn: 779.0000 - val_accuracy: 0.8778 - val_precision: 0.1891 - val_recall: 0.7632 - val_auc: 0.9010 - val_prc: 0.5326
# Epoch 133/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4182 - tp: 10320.0000 - fp: 52656.0000 - tn: 311980.0000 - fn: 2989.0000 - accuracy: 0.8528 - precision: 0.1639 - recall: 0.7754 - auc: 0.8899 - prc: 0.4489 - val_loss: 0.3214 - val_tp: 2369.0000 - val_fp: 8399.0000 - val_tn: 82798.0000 - val_fn: 921.0000 - val_accuracy: 0.9014 - val_precision: 0.2200 - val_recall: 0.7201 - val_auc: 0.8995 - val_prc: 0.5271
# Epoch 134/200
# 93/93 [==============================] - 9s 98ms/step - loss: 0.4182 - tp: 10276.0000 - fp: 52816.0000 - tn: 311820.0000 - fn: 3033.0000 - accuracy: 0.8522 - precision: 0.1629 - recall: 0.7721 - auc: 0.8898 - prc: 0.4545 - val_loss: 0.3466 - val_tp: 2497.0000 - val_fp: 10794.0000 - val_tn: 80403.0000 - val_fn: 793.0000 - val_accuracy: 0.8774 - val_precision: 0.1879 - val_recall: 0.7590 - val_auc: 0.8994 - val_prc: 0.5279
# Epoch 135/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4183 - tp: 10273.0000 - fp: 52224.0000 - tn: 312412.0000 - fn: 3036.0000 - accuracy: 0.8538 - precision: 0.1644 - recall: 0.7719 - auc: 0.8897 - prc: 0.4503 - val_loss: 0.3433 - val_tp: 2459.0000 - val_fp: 9910.0000 - val_tn: 81287.0000 - val_fn: 831.0000 - val_accuracy: 0.8863 - val_precision: 0.1988 - val_recall: 0.7474 - val_auc: 0.9010 - val_prc: 0.5301
# Epoch 136/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4174 - tp: 10238.0000 - fp: 51644.0000 - tn: 312992.0000 - fn: 3071.0000 - accuracy: 0.8552 - precision: 0.1654 - recall: 0.7693 - auc: 0.8899 - prc: 0.4568 - val_loss: 0.3480 - val_tp: 2496.0000 - val_fp: 11090.0000 - val_tn: 80107.0000 - val_fn: 794.0000 - val_accuracy: 0.8742 - val_precision: 0.1837 - val_recall: 0.7587 - val_auc: 0.9000 - val_prc: 0.5286
# Epoch 137/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4190 - tp: 10267.0000 - fp: 52828.0000 - tn: 311808.0000 - fn: 3042.0000 - accuracy: 0.8522 - precision: 0.1627 - recall: 0.7714 - auc: 0.8892 - prc: 0.4552 - val_loss: 0.3509 - val_tp: 2505.0000 - val_fp: 10520.0000 - val_tn: 80677.0000 - val_fn: 785.0000 - val_accuracy: 0.8804 - val_precision: 0.1923 - val_recall: 0.7614 - val_auc: 0.9012 - val_prc: 0.5301
# Epoch 138/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4200 - tp: 10291.0000 - fp: 53270.0000 - tn: 311366.0000 - fn: 3018.0000 - accuracy: 0.8511 - precision: 0.1619 - recall: 0.7732 - auc: 0.8889 - prc: 0.4505 - val_loss: 0.3338 - val_tp: 2449.0000 - val_fp: 9698.0000 - val_tn: 81499.0000 - val_fn: 841.0000 - val_accuracy: 0.8885 - val_precision: 0.2016 - val_recall: 0.7444 - val_auc: 0.9002 - val_prc: 0.5327
# Epoch 139/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4147 - tp: 10373.0000 - fp: 52926.0000 - tn: 311710.0000 - fn: 2936.0000 - accuracy: 0.8522 - precision: 0.1639 - recall: 0.7794 - auc: 0.8916 - prc: 0.4545 - val_loss: 0.3421 - val_tp: 2481.0000 - val_fp: 10382.0000 - val_tn: 80815.0000 - val_fn: 809.0000 - val_accuracy: 0.8816 - val_precision: 0.1929 - val_recall: 0.7541 - val_auc: 0.9019 - val_prc: 0.5388
# Epoch 140/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4155 - tp: 10324.0000 - fp: 52191.0000 - tn: 312445.0000 - fn: 2985.0000 - accuracy: 0.8540 - precision: 0.1651 - recall: 0.7757 - auc: 0.8908 - prc: 0.4586 - val_loss: 0.3481 - val_tp: 2514.0000 - val_fp: 11090.0000 - val_tn: 80107.0000 - val_fn: 776.0000 - val_accuracy: 0.8744 - val_precision: 0.1848 - val_recall: 0.7641 - val_auc: 0.9023 - val_prc: 0.5412
# Epoch 141/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4192 - tp: 10314.0000 - fp: 53044.0000 - tn: 311592.0000 - fn: 2995.0000 - accuracy: 0.8517 - precision: 0.1628 - recall: 0.7750 - auc: 0.8892 - prc: 0.4566 - val_loss: 0.3295 - val_tp: 2434.0000 - val_fp: 9225.0000 - val_tn: 81972.0000 - val_fn: 856.0000 - val_accuracy: 0.8933 - val_precision: 0.2088 - val_recall: 0.7398 - val_auc: 0.9014 - val_prc: 0.5379
# Epoch 142/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4164 - tp: 10232.0000 - fp: 51574.0000 - tn: 313062.0000 - fn: 3077.0000 - accuracy: 0.8554 - precision: 0.1656 - recall: 0.7688 - auc: 0.8899 - prc: 0.4572 - val_loss: 0.3662 - val_tp: 2529.0000 - val_fp: 11785.0000 - val_tn: 79412.0000 - val_fn: 761.0000 - val_accuracy: 0.8672 - val_precision: 0.1767 - val_recall: 0.7687 - val_auc: 0.8986 - val_prc: 0.5327
# Epoch 143/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4158 - tp: 10353.0000 - fp: 53410.0000 - tn: 311226.0000 - fn: 2956.0000 - accuracy: 0.8509 - precision: 0.1624 - recall: 0.7779 - auc: 0.8912 - prc: 0.4522 - val_loss: 0.3672 - val_tp: 2539.0000 - val_fp: 11644.0000 - val_tn: 79553.0000 - val_fn: 751.0000 - val_accuracy: 0.8688 - val_precision: 0.1790 - val_recall: 0.7717 - val_auc: 0.9028 - val_prc: 0.5368
# Epoch 144/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4169 - tp: 10302.0000 - fp: 52971.0000 - tn: 311665.0000 - fn: 3007.0000 - accuracy: 0.8519 - precision: 0.1628 - recall: 0.7741 - auc: 0.8912 - prc: 0.4563 - val_loss: 0.3571 - val_tp: 2522.0000 - val_fp: 11275.0000 - val_tn: 79922.0000 - val_fn: 768.0000 - val_accuracy: 0.8725 - val_precision: 0.1828 - val_recall: 0.7666 - val_auc: 0.9008 - val_prc: 0.5321
# Epoch 145/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4168 - tp: 10246.0000 - fp: 51341.0000 - tn: 313295.0000 - fn: 3063.0000 - accuracy: 0.8561 - precision: 0.1664 - recall: 0.7699 - auc: 0.8902 - prc: 0.4572 - val_loss: 0.3404 - val_tp: 2462.0000 - val_fp: 10009.0000 - val_tn: 81188.0000 - val_fn: 828.0000 - val_accuracy: 0.8853 - val_precision: 0.1974 - val_recall: 0.7483 - val_auc: 0.9014 - val_prc: 0.5393
# Epoch 146/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4168 - tp: 10326.0000 - fp: 53108.0000 - tn: 311528.0000 - fn: 2983.0000 - accuracy: 0.8516 - precision: 0.1628 - recall: 0.7759 - auc: 0.8906 - prc: 0.4567 - val_loss: 0.3541 - val_tp: 2524.0000 - val_fp: 11163.0000 - val_tn: 80034.0000 - val_fn: 766.0000 - val_accuracy: 0.8737 - val_precision: 0.1844 - val_recall: 0.7672 - val_auc: 0.9017 - val_prc: 0.5346
# Epoch 147/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4143 - tp: 10379.0000 - fp: 53154.0000 - tn: 311482.0000 - fn: 2930.0000 - accuracy: 0.8516 - precision: 0.1634 - recall: 0.7798 - auc: 0.8916 - prc: 0.4598 - val_loss: 0.3429 - val_tp: 2455.0000 - val_fp: 9713.0000 - val_tn: 81484.0000 - val_fn: 835.0000 - val_accuracy: 0.8884 - val_precision: 0.2018 - val_recall: 0.7462 - val_auc: 0.9015 - val_prc: 0.5368
# Epoch 148/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4132 - tp: 10317.0000 - fp: 52947.0000 - tn: 311689.0000 - fn: 2992.0000 - accuracy: 0.8520 - precision: 0.1631 - recall: 0.7752 - auc: 0.8922 - prc: 0.4586 - val_loss: 0.3420 - val_tp: 2508.0000 - val_fp: 10740.0000 - val_tn: 80457.0000 - val_fn: 782.0000 - val_accuracy: 0.8781 - val_precision: 0.1893 - val_recall: 0.7623 - val_auc: 0.9012 - val_prc: 0.5415
# Epoch 149/200
# 93/93 [==============================] - 9s 101ms/step - loss: 0.4136 - tp: 10364.0000 - fp: 53983.0000 - tn: 310653.0000 - fn: 2945.0000 - accuracy: 0.8494 - precision: 0.1611 - recall: 0.7787 - auc: 0.8926 - prc: 0.4590 - val_loss: 0.3483 - val_tp: 2486.0000 - val_fp: 10215.0000 - val_tn: 80982.0000 - val_fn: 804.0000 - val_accuracy: 0.8834 - val_precision: 0.1957 - val_recall: 0.7556 - val_auc: 0.9006 - val_prc: 0.5401
# Epoch 150/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4127 - tp: 10372.0000 - fp: 52273.0000 - tn: 312363.0000 - fn: 2937.0000 - accuracy: 0.8539 - precision: 0.1656 - recall: 0.7793 - auc: 0.8926 - prc: 0.4627 - val_loss: 0.3533 - val_tp: 2547.0000 - val_fp: 11733.0000 - val_tn: 79464.0000 - val_fn: 743.0000 - val_accuracy: 0.8680 - val_precision: 0.1784 - val_recall: 0.7742 - val_auc: 0.8983 - val_prc: 0.5301
# Epoch 151/200
# 93/93 [==============================] - 9s 101ms/step - loss: 0.4163 - tp: 10354.0000 - fp: 53702.0000 - tn: 310934.0000 - fn: 2955.0000 - accuracy: 0.8501 - precision: 0.1616 - recall: 0.7780 - auc: 0.8903 - prc: 0.4587 - val_loss: 0.3664 - val_tp: 2575.0000 - val_fp: 13192.0000 - val_tn: 78005.0000 - val_fn: 715.0000 - val_accuracy: 0.8528 - val_precision: 0.1633 - val_recall: 0.7827 - val_auc: 0.8985 - val_prc: 0.5229
# Epoch 152/200
# 93/93 [==============================] - 9s 101ms/step - loss: 0.4168 - tp: 10355.0000 - fp: 53946.0000 - tn: 310690.0000 - fn: 2954.0000 - accuracy: 0.8494 - precision: 0.1610 - recall: 0.7780 - auc: 0.8907 - prc: 0.4500 - val_loss: 0.3591 - val_tp: 2613.0000 - val_fp: 13387.0000 - val_tn: 77810.0000 - val_fn: 677.0000 - val_accuracy: 0.8512 - val_precision: 0.1633 - val_recall: 0.7942 - val_auc: 0.9010 - val_prc: 0.5421
# Epoch 153/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4164 - tp: 10435.0000 - fp: 56923.0000 - tn: 307713.0000 - fn: 2874.0000 - accuracy: 0.8418 - precision: 0.1549 - recall: 0.7841 - auc: 0.8910 - prc: 0.4520 - val_loss: 0.3457 - val_tp: 2541.0000 - val_fp: 11625.0000 - val_tn: 79572.0000 - val_fn: 749.0000 - val_accuracy: 0.8690 - val_precision: 0.1794 - val_recall: 0.7723 - val_auc: 0.9006 - val_prc: 0.5381
# Epoch 154/200
# 93/93 [==============================] - 9s 99ms/step - loss: 0.4151 - tp: 10351.0000 - fp: 52758.0000 - tn: 311878.0000 - fn: 2958.0000 - accuracy: 0.8526 - precision: 0.1640 - recall: 0.7777 - auc: 0.8918 - prc: 0.4594 - val_loss: 0.3357 - val_tp: 2491.0000 - val_fp: 10101.0000 - val_tn: 81096.0000 - val_fn: 799.0000 - val_accuracy: 0.8846 - val_precision: 0.1978 - val_recall: 0.7571 - val_auc: 0.9042 - val_prc: 0.5407
# Epoch 155/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4141 - tp: 10321.0000 - fp: 52719.0000 - tn: 311917.0000 - fn: 2988.0000 - accuracy: 0.8526 - precision: 0.1637 - recall: 0.7755 - auc: 0.8919 - prc: 0.4641 - val_loss: 0.3410 - val_tp: 2507.0000 - val_fp: 11128.0000 - val_tn: 80069.0000 - val_fn: 783.0000 - val_accuracy: 0.8739 - val_precision: 0.1839 - val_recall: 0.7620 - val_auc: 0.9010 - val_prc: 0.5301
# Epoch 156/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4126 - tp: 10327.0000 - fp: 53045.0000 - tn: 311591.0000 - fn: 2982.0000 - accuracy: 0.8518 - precision: 0.1630 - recall: 0.7759 - auc: 0.8931 - prc: 0.4632 - val_loss: 0.3301 - val_tp: 2485.0000 - val_fp: 10285.0000 - val_tn: 80912.0000 - val_fn: 805.0000 - val_accuracy: 0.8826 - val_precision: 0.1946 - val_recall: 0.7553 - val_auc: 0.9023 - val_prc: 0.5416
# Epoch 157/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4102 - tp: 10366.0000 - fp: 52296.0000 - tn: 312340.0000 - fn: 2943.0000 - accuracy: 0.8538 - precision: 0.1654 - recall: 0.7789 - auc: 0.8943 - prc: 0.4626 - val_loss: 0.3540 - val_tp: 2489.0000 - val_fp: 10305.0000 - val_tn: 80892.0000 - val_fn: 801.0000 - val_accuracy: 0.8825 - val_precision: 0.1945 - val_recall: 0.7565 - val_auc: 0.9020 - val_prc: 0.5392
# Epoch 158/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4088 - tp: 10299.0000 - fp: 51135.0000 - tn: 313501.0000 - fn: 3010.0000 - accuracy: 0.8567 - precision: 0.1676 - recall: 0.7738 - auc: 0.8947 - prc: 0.4647 - val_loss: 0.3488 - val_tp: 2526.0000 - val_fp: 11178.0000 - val_tn: 80019.0000 - val_fn: 764.0000 - val_accuracy: 0.8736 - val_precision: 0.1843 - val_recall: 0.7678 - val_auc: 0.9019 - val_prc: 0.5395
# Epoch 159/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4100 - tp: 10392.0000 - fp: 52411.0000 - tn: 312225.0000 - fn: 2917.0000 - accuracy: 0.8536 - precision: 0.1655 - recall: 0.7808 - auc: 0.8949 - prc: 0.4652 - val_loss: 0.3739 - val_tp: 2561.0000 - val_fp: 12431.0000 - val_tn: 78766.0000 - val_fn: 729.0000 - val_accuracy: 0.8607 - val_precision: 0.1708 - val_recall: 0.7784 - val_auc: 0.9012 - val_prc: 0.5391
# Epoch 160/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4124 - tp: 10400.0000 - fp: 53075.0000 - tn: 311561.0000 - fn: 2909.0000 - accuracy: 0.8519 - precision: 0.1638 - recall: 0.7814 - auc: 0.8928 - prc: 0.4592 - val_loss: 0.3583 - val_tp: 2547.0000 - val_fp: 11377.0000 - val_tn: 79820.0000 - val_fn: 743.0000 - val_accuracy: 0.8717 - val_precision: 0.1829 - val_recall: 0.7742 - val_auc: 0.9038 - val_prc: 0.5409
# Epoch 161/200
# 93/93 [==============================] - 9s 100ms/step - loss: 0.4096 - tp: 10395.0000 - fp: 51912.0000 - tn: 312724.0000 - fn: 2914.0000 - accuracy: 0.8549 - precision: 0.1668 - recall: 0.7811 - auc: 0.8942 - prc: 0.4669 - val_loss: 0.3345 - val_tp: 2429.0000 - val_fp: 9353.0000 - val_tn: 81844.0000 - val_fn: 861.0000 - val_accuracy: 0.8919 - val_precision: 0.2062 - val_recall: 0.7383 - val_auc: 0.9008 - val_prc: 0.5379
# Epoch 162/200
# 92/93 [============================>.] - ETA: 0s - loss: 0.4133 - tp: 10256.0000 - fp: 49794.0000 - tn: 313767.0000 - fn: 3015.0000 - accuracy: 0.8599 - precision: 0.1708 - recall: 0.7728 - auc: 0.8918 - prc: 0.4666Restoring model weights from the end of the best epoch: 152.
# 93/93 [==============================] - 9s 102ms/step - loss: 0.4132 - tp: 10288.0000 - fp: 49951.0000 - tn: 314685.0000 - fn: 3021.0000 - accuracy: 0.8598 - precision: 0.1708 - recall: 0.7730 - auc: 0.8919 - prc: 0.4666 - val_loss: 0.3490 - val_tp: 2534.0000 - val_fp: 11101.0000 - val_tn: 80096.0000 - val_fn: 756.0000 - val_accuracy: 0.8745 - val_precision: 0.1858 - val_recall: 0.7702 - val_auc: 0.9010 - val_prc: 0.5378
# Epoch 162: early stopping

# %%
import matplotlib as mpl
import matplotlib.pylab as plt
import seaborn as sns

mpl.rcParams['figure.figsize'] = (12, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

def plot_metrics(history):
  metrics = ['loss', 'prc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend();

plot_metrics(weighted_history)

# %%
train_predictions_weighted = weighted_model.predict(train_features, batch_size=BATCH_SIZE)
test_predictions_weighted = weighted_model.predict(test_features, batch_size=BATCH_SIZE)

# %%
def plot_cm(labels, predictions, p=0.5):
  cm = confusion_matrix(labels, predictions > p)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('Legitimate Transactions Detected (True Negatives): ', cm[0][0])
  print('Legitimate Transactions Incorrectly Detected (False Positives): ', cm[0][1])
  print('Fraudulent Transactions Missed (False Negatives): ', cm[1][0])
  print('Fraudulent Transactions Detected (True Positives): ', cm[1][1])
  print('Total Fraudulent Transactions: ', np.sum(cm[1]))

# %%
weighted_results = weighted_model.evaluate(test_features, test_labels,
                                           batch_size=BATCH_SIZE, verbose=0)
for name, value in zip(weighted_model.metrics_names, weighted_results):
  print(name, ': ', value)
print()

#plot_cm(test_labels, test_predictions_weighted)
plot_confusion_matrix(test_labels, test_predictions_weighted >0.5)
# Out:
# loss :  0.40590912103652954
# tp :  2814.0
# fp :  17390.0
# tn :  96654.0
# fn :  1250.0
# accuracy :  0.8421783447265625
# precision :  0.1392793506383896
# recall :  0.6924212574958801
# auc :  0.8446878790855408
# prc :  0.35517287254333496

# %%
pos_features = train_features[bool_train_labels]
neg_features = train_features[~bool_train_labels]

pos_labels = train_labels[bool_train_labels]
neg_labels = train_labels[~bool_train_labels]

# %%
ids = np.arange(len(pos_features))
choices = np.random.choice(ids, len(neg_features))

res_pos_features = pos_features[choices]
res_pos_labels = pos_labels[choices]

res_pos_features.shape
# Out:
# (364650, 431)

# %%
resampled_features = np.concatenate([res_pos_features, neg_features], axis=0)
resampled_labels = np.concatenate([res_pos_labels, neg_labels], axis=0)

order = np.arange(len(resampled_labels))
np.random.shuffle(order)
resampled_features = resampled_features[order]
resampled_labels = resampled_labels[order]

resampled_features.shape

# %%
def plot_roc(name, labels, predictions, **kwargs):
  fp, tp, _ = sklearn.metrics.roc_curve(labels, predictions)
  auc_sc = sklearn.metrics.auc(fp, tp)
  #plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
  plt.plot(100*fp, 100*tp, label=name % auc_sc)
  plt.xlabel('False positives [%]')
  plt.ylabel('True positives [%]')
  plt.xlim([-5,105])
  plt.ylim([-5,105])
  plt.grid(True)
  ax = plt.gca()
  ax.set_aspect('equal')

# %%
plot_roc("Weighted NN", test_labels, test_predictions_weighted, color=colors[0], linestyle='--')
final_test_pred= pd.read_csv("/gdrive/My Drive/AIML/Project/test_pred_RF.csv")
plot_roc("RandomForrest", final_test_pred.Actual, final_test_pred.pred_rf, color=colors[1], linestyle='--')
final_test_pred= pd.read_csv("/gdrive/My Drive/AIML/Project/test_pred_xg.csv")
plot_roc("XGBoost", final_test_pred.Actual, final_test_pred.pred_xg, color=colors[2], linestyle='--')

plt.legend(loc='lower right');
plt.show()
